# %% [markdown]
# # Model #3 Multivariate CNN (Diesel -> Spot Price)
# * Import fuel_prices_com.csv & GBP_USD.csv
# * Using Fuel Prices and Forex Spot Price as input into an CNN model to predict Forex Spot Price of the currency pair in question.

# %% [markdown]
# # Imports

# %%
# Imports
# !pip install git+https://github.com/tensorflow/docs
import tensorflow as tf
print(tf.__version__)

# Libraries
import pathlib
import numpy as np
import pandas as pd
from numpy import array

# Plotting
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
plt.style.use('seaborn')
from matplotlib import rcParams

# Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, Flatten, Dropout
from numpy.random import seed
from random import shuffle

# Metric
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-be6prgan
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-be6prgan
# Requirement already satisfied (use --upgrade to upgrade): tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968- from git+https://github.com/tensorflow/docs in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: astor in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (49.6.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968_-cp36-none-any.whl size=146353 sha256=af8ec0a7142acd422273f8bdde9a08fdefbb5252073519c7a602055e74088782
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gw_hnbu6/wheels/eb/1b/35/fce87697be00d2fc63e0b4b395b0d9c7e391a10e98d9a0d97f
# Successfully built tensorflow-docs
# 2.3.0

# %%
seed(1)
tf.random.set_seed(2)

# %% [markdown]
# # Data Collection

# %%
# Import forex
forex_dataset_data= pd.read_csv('GBP_USD.csv', na_values = "?", comment='\t', skipinitialspace=True)
forex_dataset = forex_dataset_data.copy()
forex_dataset = forex_dataset.fillna(method='ffill')
forex_dataset = pd.DataFrame(forex_dataset,columns=['Price','Date'])

# %%
# Import price
fuel_dataset = pd.read_csv('fuel_prices_com.csv', encoding= 'unicode_escape')
fuel_dataset = fuel_dataset.loc[fuel_dataset.Country=='USA', ['Date','Diesel']]

# %% [markdown]
# # Data Preprocessing / Data Cleaning & Collating
# *   We first isolate the date column both fuel_dataset and forex_dataset so that they are formatted in the same way.
# *   Challenge: Fuel Price dataset is a weekly timeseries dataset whereas Forex Price is a daily timeseries dataset.

# %%
fuel_dataset['Date'] = fuel_dataset['Date'].apply(lambda x: pd.to_datetime(str(x)))
fuel_dataset['Date'].head()
# Out:
# 772   2020-06-01
# 773   2020-01-13
# 774   2020-01-20
# 775   2020-01-27
# 776   2020-03-02
# Name: Date, dtype: datetime64[ns]

# %%
# We find out the format for where the day, month and year lie.
fuel_dataset["Date"] = pd.to_datetime(fuel_dataset["Date"], format="%d-%m-%Y")
forex_dataset["Date"] = pd.to_datetime(forex_dataset["Date"], format="%b %d, %Y")
# We transform these values to the same format.
fuel_dataset["Date"] = fuel_dataset["Date"].dt.strftime("%d-%m-%Y")
forex_dataset["Date"] = forex_dataset["Date"].dt.strftime("%d-%m-%Y")
# We then convert them back to a dataframe.
fuel_dataset["Date"] = pd.to_datetime(fuel_dataset["Date"], format="%d-%m-%Y")
forex_dataset["Date"] = pd.to_datetime(forex_dataset["Date"], format="%d-%m-%Y")

# %%
# We set the index for both datasets to be date.
forex_dataset.set_index("Date", inplace=True)
fuel_dataset.set_index("Date", inplace=True)
forex_dataset["Date"] = forex_dataset.index
fuel_dataset["date"] = fuel_dataset.index

# %%
# We then group these dates in a weekly period column
fuel_dataset["week"] = fuel_dataset.index.to_period('W')
forex_dataset["week"] = forex_dataset.index.to_period('W')

# %%
# We then join our datasets on the week column
data_ff = pd.merge(
    forex_dataset,
    fuel_dataset,
    left_on="week",
    right_on="week",
    how="left"
)

# %%
data_ff[data_ff.Diesel.isnull() | data_ff.Price.isnull()]
# Out:
#       Price       Date                   week  Diesel date
# 0    1.3090 2020-07-31  2020-07-27/2020-08-02     NaN  NaT
# 1    1.3095 2020-07-30  2020-07-27/2020-08-02     NaN  NaT
# 2    1.2996 2020-07-29  2020-07-27/2020-08-02     NaN  NaT
# 3    1.2932 2020-07-28  2020-07-27/2020-08-02     NaN  NaT
# 4    1.2882 2020-07-27  2020-07-27/2020-08-02     NaN  NaT
# 19   1.2554 2020-07-12  2020-07-06/2020-07-12     NaN  NaT
# 20   1.2554 2020-07-11  2020-07-06/2020-07-12     NaN  NaT
# 21   1.2622 2020-07-10  2020-07-06/2020-07-12     NaN  NaT
# 22   1.2607 2020-07-09  2020-07-06/2020-07-12     NaN  NaT
# 23   1.2611 2020-07-08  2020-07-06/2020-07-12     NaN  NaT
# 24   1.2542 2020-07-07  2020-07-06/2020-07-12     NaN  NaT
# 25   1.2493 2020-07-06  2020-07-06/2020-07-12     NaN  NaT
# 47   1.2604 2020-06-14  2020-06-08/2020-06-14     NaN  NaT
# 48   1.2604 2020-06-13  2020-06-08/2020-06-14     NaN  NaT
# 49   1.2542 2020-06-12  2020-06-08/2020-06-14     NaN  NaT
# 50   1.2602 2020-06-11  2020-06-08/2020-06-14     NaN  NaT
# 51   1.2747 2020-06-10  2020-06-08/2020-06-14     NaN  NaT
# 52   1.2731 2020-06-09  2020-06-08/2020-06-14     NaN  NaT
# 53   1.2723 2020-06-08  2020-06-08/2020-06-14     NaN  NaT
# 89   1.2193 2020-05-17  2020-05-11/2020-05-17     NaN  NaT
# 90   1.2193 2020-05-16  2020-05-11/2020-05-17     NaN  NaT
# 91   1.2106 2020-05-15  2020-05-11/2020-05-17     NaN  NaT
# 92   1.2228 2020-05-14  2020-05-11/2020-05-17     NaN  NaT
# 93   1.2230 2020-05-13  2020-05-11/2020-05-17     NaN  NaT
# 94   1.2261 2020-05-12  2020-05-11/2020-05-17     NaN  NaT
# 95   1.2336 2020-05-11  2020-05-11/2020-05-17     NaN  NaT
# 96   1.2336 2020-05-10  2020-05-04/2020-05-10     NaN  NaT
# 97   1.2336 2020-05-09  2020-05-04/2020-05-10     NaN  NaT
# 98   1.2409 2020-05-08  2020-05-04/2020-05-10     NaN  NaT
# 99   1.2363 2020-05-07  2020-05-04/2020-05-10     NaN  NaT
# 100  1.2343 2020-05-06  2020-05-04/2020-05-10     NaN  NaT
# 101  1.2436 2020-05-05  2020-05-04/2020-05-10     NaN  NaT
# 102  1.2444 2020-05-04  2020-05-04/2020-05-10     NaN  NaT
# 124  1.2512 2020-04-12  2020-04-06/2020-04-12     NaN  NaT
# 125  1.2512 2020-04-11  2020-04-06/2020-04-12     NaN  NaT
# 126  1.2455 2020-04-10  2020-04-06/2020-04-12     NaN  NaT
# 127  1.2457 2020-04-09  2020-04-06/2020-04-12     NaN  NaT
# 128  1.2387 2020-04-08  2020-04-06/2020-04-12     NaN  NaT
# 129  1.2339 2020-04-07  2020-04-06/2020-04-12     NaN  NaT
# 130  1.2230 2020-04-06  2020-04-06/2020-04-12     NaN  NaT
# 159  1.2268 2020-03-15  2020-03-09/2020-03-15     NaN  NaT
# 160  1.2268 2020-03-14  2020-03-09/2020-03-15     NaN  NaT
# 161  1.2277 2020-03-13  2020-03-09/2020-03-15     NaN  NaT
# 162  1.2573 2020-03-12  2020-03-09/2020-03-15     NaN  NaT
# 163  1.2822 2020-03-11  2020-03-09/2020-03-15     NaN  NaT
# 164  1.2908 2020-03-10  2020-03-09/2020-03-15     NaN  NaT
# 165  1.3133 2020-03-09  2020-03-09/2020-03-15     NaN  NaT
# 187  1.3009 2020-02-16  2020-02-10/2020-02-16     NaN  NaT
# 188  1.3009 2020-02-15  2020-02-10/2020-02-16     NaN  NaT
# 189  1.3047 2020-02-14  2020-02-10/2020-02-16     NaN  NaT
# 190  1.3047 2020-02-13  2020-02-10/2020-02-16     NaN  NaT
# 191  1.2961 2020-02-12  2020-02-10/2020-02-16     NaN  NaT
# 192  1.2953 2020-02-11  2020-02-10/2020-02-16     NaN  NaT
# 193  1.2915 2020-02-10  2020-02-10/2020-02-16     NaN  NaT
# 229  1.3169 2020-01-05  2019-12-30/2020-01-05     NaN  NaT
# 230  1.3169 2020-01-04  2019-12-30/2020-01-05     NaN  NaT
# 231  1.3088 2020-01-03  2019-12-30/2020-01-05     NaN  NaT
# 232  1.3146 2020-01-02  2019-12-30/2020-01-05     NaN  NaT
# 233  1.3255 2020-01-01  2019-12-30/2020-01-05     NaN  NaT
# 234  1.3261 2019-12-31  2019-12-30/2020-01-05     NaN  NaT

# %%
# We isolate the features that we want in our dataset
data_ff = pd.DataFrame(data_ff, columns = ['Date', 'Price', 'Diesel']) 
data_ff['Diesel'].fillna((data_ff['Diesel'].mean()), inplace=True) # Notice how our dataset starts from the end rather than the top
dataset = data_ff.iloc[::-1,:] # Reverse order of dataset
dataset.reset_index(drop=True, inplace=True) #Reset index

# %%
dataset = pd.DataFrame(dataset, columns = ['Date', 'Price', 'Diesel']) 
dataset
# Out:
#           Date   Price   Diesel
# 0   2019-12-31  1.3261  0.69532
# 1   2020-01-01  1.3255  0.69532
# 2   2020-01-02  1.3146  0.69532
# 3   2020-01-03  1.3088  0.69532
# 4   2020-01-04  1.3169  0.69532
# ..         ...     ...      ...
# 230 2020-07-27  1.2882  0.69532
# 231 2020-07-28  1.2932  0.69532
# 232 2020-07-29  1.2996  0.69532
# 233 2020-07-30  1.3095  0.69532
# 234 2020-07-31  1.3090  0.69532
#
# [235 rows x 3 columns]

# %% [markdown]
# # Plotting Features before Normalisation

# %% [markdown]
# ### Organising date for plotting

# %%
# Isolate date for plotting
date = dataset['Date']
# Isolate dates in question
dateFormatting = pd.DataFrame({'new_date': pd.date_range('2019-12-31', '2020-07-31', periods=len(date))})
# Convert date to list so that we can use the dates to plot on graph
my_xticks = dateFormatting['new_date'].tolist()

# %% [markdown]
# ### Plotting Forex Spot Price

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
price = np.array(dataset['Price'])
plt.plot_date(dates,price, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series Price of Forex Spot Price', size = 20)
plt.xlabel('Date')
plt.ylabel('Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# ### Plotting Diesel Prices

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
fuel = np.array(dataset['Diesel'])
plt.plot_date(dates,fuel, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series of Fuel Prices', size = 20)
plt.xlabel('Date')
plt.ylabel('Fuel Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# # Plotting Features after Normalisation

# %%
price_frame = pd.DataFrame(np.concatenate([price]), columns= ["Price"])
fuel_frame = pd.DataFrame(np.concatenate([fuel]), columns= ["Fuel Price"])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
normalisation_price = scaler.fit_transform(price_frame).reshape(-1,1)
normalisation_fuel_price = scaler.fit_transform(fuel_frame).reshape(-1,1)

# %%
rcParams['figure.figsize'] = 15,6
plt.plot(normalisation_price, label="Spot Price")
plt.plot(normalisation_fuel_price, label="Fuel Price")
dates = np.array(dateFormatting['new_date'])
plt.title('Time Series of Fuel Prices & Forex Price', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend() 
plt.show()

# %% [markdown]
# # Splitting Data into Train, Validation & Test

# %%
new_dataset = np.hstack((normalisation_fuel_price, normalisation_price))

# %%
# Test, Validation, Train 
training_size = int(len(new_dataset)*0.80)
test_size = (len(new_dataset)-training_size)//2 # // Rounds down
train_data, valset_data, test_data = new_dataset[0:training_size], new_dataset[training_size:(training_size + test_size)],new_dataset[(training_size + test_size):]
print(train_data.shape)
print(valset_data.shape)
print(test_data.shape)
# Out:
# (188, 2)
# (23, 2)
# (24, 2)

# %%
# Start – Train
rcParams['figure.figsize'] = 15,6
plt.plot(train_data, label="Actual Train Dataset")
plt.title('Normalised Train Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# Middle – Validation
rcParams['figure.figsize'] = 15,6
plt.plot(valset_data, label="Actual validation dataset")
plt.title('Normalised Validation Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# End - Test
rcParams['figure.figsize'] = 15,6
plt.plot(test_data, label="Actual test dataset")
plt.title('Normalised Test Data', size =20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# # X_train, Y_train, X_test, Y_test

# %%
# Convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
  dataX, dataY = [],[]
  # range: is the days in dataset - the days we need to consider - the 8th day
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step)]  # from i -> 6th day
    dataX.append(a) 
    y = dataset[i + time_step][1] # 7th day
    dataY.append(y)
  return np.array(dataX), np.array(dataY)

# %%
# Weekly_timestep means taking in 7 days of features at a time 
weekly_timestep = 7
X_train, Y_train = create_dataset(train_data, weekly_timestep)
X_val, Y_val = create_dataset(valset_data, weekly_timestep)
X_test, Y_test = create_dataset(test_data, weekly_timestep)

# %% [markdown]
# # Reshape for CNN

# %%
print('Before reshape')
print(X_train.shape), print(Y_train.shape)
print(X_val.shape), print(Y_val.shape)
print(X_test.shape), print(Y_test.shape)

X_train = X_train.reshape(180,7,2,1)
X_val = X_val.reshape(15,7,2,1)
X_test = X_test.reshape(16,7,2,1)

print('After reshape')
print(X_train.shape), print(Y_train.shape)
print(X_val.shape), print(Y_val.shape)
print(X_test.shape), print(Y_test.shape)
# Out:
# Before reshape
# (180, 7, 2)
# (180,)
# (15, 7, 2)
# (15,)
# (16, 7, 2)
# (16,)
# After reshape
# (180, 7, 2, 1)
# (180,)
# (15, 7, 2, 1)
# (15,)
# (16, 7, 2, 1)
# (16,)
# (None, None)

# %% [markdown]
# # CNN Model

# %%
def cnn_model(lr_rate, filters_layers, optimizer_one):

  opt = None
  if optimizer_one == 'adam':
   opt = keras.optimizers.Adam(learning_rate=lr_rate)
  elif optimizer_one == 'sgd':
   opt = keras.optimizers.SGD(learning_rate=lr_rate)
  else:
   opt = keras.optimizers.Adamax(learning_rate=lr_rate)

  cnn = Sequential([
    
  Conv2D(filters= filters_layers, input_shape=(7, 2, 1), kernel_size=(7,1), strides=1),
  Dropout(0.5),
  # Dense(64),
  Conv2D(filters= filters_layers, kernel_size=(1,1), strides=1),
  Dropout(0.2),
  # Dense(10), #
  Flatten(), # to make 1D
  Dense(1) # output feature map
  ])
  cnn.compile(loss = 'mean_squared_error', optimizer= opt)
  # print(cnn.summary())
  return cnn

# %% [markdown]
# ## Hyperparameter Tuning
# ![Grid Search & Random Search](https://miro.medium.com/max/1200/1*ZTlQm_WRcrNqL-nLnx6GJA.png)

# %%
# Function to create the best model for hyperparameters method
def bestModel(least_loss, learning_rate_list, optimizer_list, filter_list):
  for each_filter in filter_list:
    for each_optimizer in optimizer_list:
      for each_learning_rate in learning_rate_list:
        our_model = cnn_model(each_learning_rate, each_filter, each_optimizer)
        our_model.fit(X_train, Y_train, 
                validation_data= 
                (X_val, Y_val)
                , epochs=100,batch_size=10,verbose=1,
                callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)])
        loss = our_model.evaluate(X_test, Y_test)
        if loss < least_loss:
          least_loss = loss
          best_learning_rate = each_learning_rate
          best_optimizer = each_optimizer
          best_filter= each_filter
    return least_loss, best_learning_rate, best_optimizer, best_filter

# %% [markdown]
# ### Grid Search

# %%
filter_list = [15,30,10]
optimizer_list = ['adam', 'adamax']
learning_rate_list = [3e-3,3e-4]
least_loss_grid_search = 1

best_grid_search_model = bestModel(least_loss_grid_search, learning_rate_list, optimizer_list, filter_list)
print(best_grid_search_model)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.1440 - val_loss: 0.0192
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1101 - val_loss: 0.0251
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0530 - val_loss: 0.0065
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0544 - val_loss: 0.0072
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0353 - val_loss: 0.0032
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0349 - val_loss: 0.0032
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0374 - val_loss: 0.0024
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0326 - val_loss: 0.0025
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0295 - val_loss: 0.0026
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.0047
# 1/1 [==============================] - 0s 920us/step - loss: 0.0217
# Epoch 1/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.2488 - val_loss: 0.0991
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2169 - val_loss: 0.0648
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1962 - val_loss: 0.0484
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1488 - val_loss: 0.0375
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1574 - val_loss: 0.0414
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1399 - val_loss: 0.0315
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1199 - val_loss: 0.0275
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1257 - val_loss: 0.0260
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0941 - val_loss: 0.0267
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0979 - val_loss: 0.0246
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1031 - val_loss: 0.0201
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0985 - val_loss: 0.0209
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0839 - val_loss: 0.0178
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0841 - val_loss: 0.0143
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0705 - val_loss: 0.0153
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0606 - val_loss: 0.0125
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0674 - val_loss: 0.0091
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0599 - val_loss: 0.0078
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0735 - val_loss: 0.0080
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0472 - val_loss: 0.0084
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0539 - val_loss: 0.0079
# 1/1 [==============================] - 0s 969us/step - loss: 0.0411
# Epoch 1/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.5252 - val_loss: 0.0057
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2161 - val_loss: 0.0119
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1426 - val_loss: 0.0246
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1171 - val_loss: 0.0171
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0517
# Epoch 1/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.6191 - val_loss: 0.1697
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5113 - val_loss: 0.1284
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3757 - val_loss: 0.0964
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3194 - val_loss: 0.0722
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3080 - val_loss: 0.0543
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2034 - val_loss: 0.0410
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2388 - val_loss: 0.0321
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1528 - val_loss: 0.0250
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1743 - val_loss: 0.0194
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1371 - val_loss: 0.0153
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1704 - val_loss: 0.0122
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1459 - val_loss: 0.0103
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1192 - val_loss: 0.0091
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1388 - val_loss: 0.0078
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1110 - val_loss: 0.0071
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1332 - val_loss: 0.0061
# Epoch 17/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1305 - val_loss: 0.0056
# Epoch 18/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1254 - val_loss: 0.0051
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1271 - val_loss: 0.0050
# Epoch 20/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1032 - val_loss: 0.0048
# Epoch 21/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1231 - val_loss: 0.0043
# Epoch 22/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1235 - val_loss: 0.0040
# Epoch 23/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1196 - val_loss: 0.0037
# Epoch 24/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1086 - val_loss: 0.0038
# Epoch 25/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0913 - val_loss: 0.0039
# Epoch 26/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0979 - val_loss: 0.0041
# 1/1 [==============================] - 0s 915us/step - loss: 0.0236
# (0.021741792559623718, 0.003, 'adam', 15)

# %% [markdown]
# ### Random Search

# %%
# Shuffle filters

filter_list = [15,30,10]
# Seed random number generator
seed(len(filter_list))
# Prepare a sequence
filter_sequence = filter_list
print(filter_sequence) # Before Shuffle
# Randomly shuffle the sequence hidden layers
shuffle(filter_sequence) 
print(filter_sequence) # After Shuffle
# Out:
# [15, 30, 10]
# [10, 15, 30]

# %%
# Shuffling optimizers

optimizer_list = ['adam', 'adamax']
# Seed random number generator
seed(len(filter_sequence))
# Prepare a sequence
op_sequence = optimizer_list
print(op_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(op_sequence)
print(op_sequence) # After Shuffle
# Out:
# ['adam', 'adamax']
# ['adamax', 'adam']

# %%
# Shuffling learning rate

learning_rate_list = [3e-3,3e-4]
# Seed random number generator
seed(len(filter_sequence))
# Prepare a sequence
lr_sequence = learning_rate_list
print(lr_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(lr_sequence)
print(lr_sequence) # After Shuffle
# Out:
# [0.003, 0.0003]
# [0.003, 0.0003]

# %%
# Assigning least_loss
least_loss_random_search = 1

# %%
best_random_grid_model = bestModel(least_loss_random_search, lr_sequence, op_sequence, filter_sequence)
print(best_random_grid_model)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2376 - val_loss: 0.0058
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3411 - val_loss: 0.0440
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2861 - val_loss: 0.0151
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2095 - val_loss: 0.0082
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0218
# Epoch 1/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.3168 - val_loss: 0.1433
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2023 - val_loss: 0.1104
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1972 - val_loss: 0.0883
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1426 - val_loss: 0.0699
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1516 - val_loss: 0.0588
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1472 - val_loss: 0.0520
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1323 - val_loss: 0.0453
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1259 - val_loss: 0.0394
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1177 - val_loss: 0.0353
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1321 - val_loss: 0.0332
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1387 - val_loss: 0.0323
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1162 - val_loss: 0.0310
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1219 - val_loss: 0.0301
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1069 - val_loss: 0.0302
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1417 - val_loss: 0.0294
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1332 - val_loss: 0.0276
# Epoch 17/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0898 - val_loss: 0.0271
# Epoch 18/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1017 - val_loss: 0.0261
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1023 - val_loss: 0.0253
# Epoch 20/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1009 - val_loss: 0.0239
# Epoch 21/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1091 - val_loss: 0.0215
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1095 - val_loss: 0.0216
# Epoch 23/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0809 - val_loss: 0.0212
# Epoch 24/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0937 - val_loss: 0.0203
# Epoch 25/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0733 - val_loss: 0.0208
# Epoch 26/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0845 - val_loss: 0.0202
# Epoch 27/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0824 - val_loss: 0.0198
# Epoch 28/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1019 - val_loss: 0.0179
# Epoch 29/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0870 - val_loss: 0.0179
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0851 - val_loss: 0.0173
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0873 - val_loss: 0.0175
# Epoch 32/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0827 - val_loss: 0.0168
# Epoch 33/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0873 - val_loss: 0.0153
# Epoch 34/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0819 - val_loss: 0.0149
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0773 - val_loss: 0.0143
# Epoch 36/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0701 - val_loss: 0.0132
# Epoch 37/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0974 - val_loss: 0.0121
# Epoch 38/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0727 - val_loss: 0.0111
# Epoch 39/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0699 - val_loss: 0.0108
# Epoch 40/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0775 - val_loss: 0.0116
# Epoch 41/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0642 - val_loss: 0.0113
# Epoch 42/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0663 - val_loss: 0.0121
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0536
# Epoch 1/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.3180 - val_loss: 0.0035
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1057 - val_loss: 0.0135
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0669 - val_loss: 0.0051
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.0036
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0078
# Epoch 1/100
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3599 - val_loss: 0.1232
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3477 - val_loss: 0.0812
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2188 - val_loss: 0.0507
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1853 - val_loss: 0.0298
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1630 - val_loss: 0.0177
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1381 - val_loss: 0.0095
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0923 - val_loss: 0.0069
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1093 - val_loss: 0.0061
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1039 - val_loss: 0.0063
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0950 - val_loss: 0.0059
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1048 - val_loss: 0.0051
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0843 - val_loss: 0.0039
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0825 - val_loss: 0.0041
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0880 - val_loss: 0.0045
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0790 - val_loss: 0.0049
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0315
# (0.007764935959130526, 0.003, 'adam', 10)

# %% [markdown]
# #### Deciding on best hyperparameter results

# %%
# We want the smallest loss
# 0 = least loss, 1 = learning rate, 2 = optimizer, 3 = neurons
if best_grid_search_model[0] > best_random_grid_model[0]:
  best_learning_rate = best_random_grid_model[1]
  best_optimizer = best_random_grid_model[2]
  best_filter = best_random_grid_model[3]
else:
  best_learning_rate = best_grid_search_model[1]
  best_optimizer = best_grid_search_model[2]
  best_filter = best_grid_search_model[3]
print(best_learning_rate)
print(best_optimizer)
print(best_filter)
# Out:
# 0.003
# adam
# 10

# %% [markdown]
# # Best Model Prediction

# %%
best_param_model = cnn_model(best_learning_rate, best_filter, best_optimizer)
best_param_model.fit(X_train, Y_train, epochs=150,batch_size=10,verbose=1)
loss = best_param_model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2106
# Epoch 2/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1173
# Epoch 3/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0607
# Epoch 4/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0475
# Epoch 5/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0533
# Epoch 6/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0520
# Epoch 7/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0422
# Epoch 8/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 9/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 10/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0355
# Epoch 11/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0288
# Epoch 12/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 13/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0233
# Epoch 14/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 15/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 16/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 17/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0222
# Epoch 18/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0227
# Epoch 19/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0201
# Epoch 20/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 21/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 22/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 23/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0157
# Epoch 24/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0193
# Epoch 25/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 26/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 27/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 28/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 29/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 30/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0163
# Epoch 31/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 32/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 33/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 34/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 35/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 36/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 37/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 38/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 39/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 40/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 41/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 42/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 43/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 44/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 45/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 46/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 47/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0154
# Epoch 48/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 49/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 50/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 51/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 52/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 53/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 54/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 55/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 56/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 57/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 58/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0159
# Epoch 59/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 60/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 61/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 62/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 63/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 64/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 65/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 66/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 67/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 68/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 69/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 70/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 71/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 72/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 73/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 74/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 75/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 76/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 77/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 78/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 79/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 80/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 81/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 82/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 83/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 84/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 85/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 86/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 87/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 88/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 89/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 90/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 91/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 92/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 93/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 94/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 95/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 96/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 97/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 98/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 99/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 100/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0095
# Epoch 101/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 102/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 103/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 104/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 105/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 106/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 107/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 108/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 109/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 110/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 111/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 112/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 113/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 114/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 115/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0106
# Epoch 116/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 117/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 118/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 119/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 120/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 121/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 122/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 123/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 124/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 125/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 126/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 127/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 128/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 129/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 130/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 131/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 132/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 133/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 134/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 135/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 136/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 137/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 138/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 139/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 140/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 141/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 142/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 143/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 144/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 145/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 146/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 147/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 148/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 149/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 150/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0070
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0063

# %% [markdown]
# # Using best model to predict on X_train & X_test

# %%
# Prediction and check performance metric
train_predict = best_param_model.predict(X_train)
test_predict = best_param_model.predict(X_test)
print(train_predict.shape)
print(test_predict.shape)
# Out:
# (180, 1)
# (16, 1)

# %% [markdown]
# # Performance Metric

# %%
def get_performance_train (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_train, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_train, model_pred).round(4))
  print('R2_Score:',r2_score(Y_train, model_pred).round(4))

# %%
def get_performance_test (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_test, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_test, model_pred).round(4))  
  print('R2_Score:',r2_score(Y_test, model_pred).round(4))

# %%
print('Train:')
get_performance_train(train_predict)
print('\nTest:')
get_performance_test(test_predict)
# Out:
# Train:
# Mean Absolute Error: 0.0455
# Mean Squared Error: 0.0038
# R2_Score: 0.9114
#
# Test:
# Mean Absolute Error: 0.0746
# Mean Squared Error: 0.0063
# R2_Score: 0.1717

# %% [markdown]
# # Plotting Train Prediction, Validation & Test Prediction Versus Actual Data

# %%
# Transform back to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict =scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Train Predicted

# %%
look_back = 7

trainPredictPlot = np.empty_like(new_dataset) # shape
trainPredictPlot[:,:]= np.nan # values 0
trainPredictPlot[look_back:len(train_predict)+look_back] = train_predict # Populates: 7 -> 162 + 7 = 169

trainPredictPlot = [item[0] for item in trainPredictPlot]
plt.plot(trainPredictPlot, label="train_predict_price")

train_panda = pd.DataFrame(train_data)
plt.plot(scaler.inverse_transform(train_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# ## Using last 7 days of training data to predict validation data.

# %%
temp_input = train_data[-7:]

# %%
# Demonstrate prediction for the next e.g.4 days:

# Step 1. 7 days of feature = temp_input taken from the last 7 days of the training set
# Step 2  i is the day you are on and we want to predict 4 days: 0,1,2,3 (4 days)
# Step 3. Predict the 8th day on each of the 7 days,
# Step 4. Add this new predicted day to the list
# Step 5. Because we are now taking in the last 7 days + the new predicted value, the list is now size 8  
# Step 6. In order to take in 7 days at a time, we shift 1 to the right.
# Step 7. We reassign the X_train to the new 7 days
# Step 8. We predict the 8th day of the 7 days and continue the process
# Step 9. We then add the 8th day to the output list
# Step 10. We keep track of the 4 days by incrementing by i at the end-> i = i+1
# Step 11. Once we have predicted the 4 days, we return the list of 4 day values.


custom_day = len(valset_data)
lst_output=[]
n_steps=7
i=0
X_input = temp_input
while(i<custom_day):
  if(len(temp_input)>7):
    X_input=array(temp_input[1:])
    X_input=X_input.reshape((1,n_steps,2, 1))
    Y_hat = best_param_model.predict(X_input)
    temp_input = np.append(temp_input, Y_hat)
    temp_input=temp_input[1:]
    lst_output.append(Y_hat[0][0])
    i=i+1
  else:
    X_input=X_input.reshape((1,n_steps,2, 1))
    Y_hat = best_param_model.predict(X_input, verbose=0)
    temp_input = np.append(temp_input, Y_hat)
    lst_output.append(Y_hat[0][0])
    i=i+1
print(lst_output)
# Out:
# [0.60122895, 0.560204, 0.56873894, 0.61020374, 0.58152443, 0.5990937, 0.5989111, 0.61386305, 0.60514206, 0.62403965, 0.613195, 0.6259709, 0.62012243, 0.6140521, 0.6161637, 0.61647993, 0.6104026, 0.60959744, 0.60788244, 0.6050444, 0.6014713, 0.5998388, 0.59617203]

# %% [markdown]
# ## Plotting evaluation: Training Prediction of Validation Data.

# %%
day_new = custom_day-1

# Predicted days from training
# Transform back to original value before normalised
custom_day_prediction = np.array(lst_output)
# print("Predicted validation:")
# print(custom_day_prediction)
plt.plot(custom_day_prediction, label="Predicted Validation Data")

# Transform back to original value before normalised
val_data = [item[1] for item in valset_data] 
custom_day_validation = val_data[:custom_day]
# print("Actual validation:")
# print(custom_day_validation)
plt.plot(custom_day_validation, label="Actual Validation Data")

# Information
rcParams['figure.figsize'] = 15,6
plt.title('Training Prediction of Validation Data', size = 20)
plt.xlabel('Days predicted')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Plot

# %%
look_back = 7

testPredictPlot = np.empty_like(new_dataset)
testPredictPlot[:,:]= np.nan
testPredictPlot[look_back:len(test_predict)+look_back] = test_predict
testPredictPlot = [item[1] for item in testPredictPlot]
plt.plot(testPredictPlot, label="test_predict")

test_panda = pd.DataFrame(test_data)
plt.plot(scaler.inverse_transform(test_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train, test and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()
