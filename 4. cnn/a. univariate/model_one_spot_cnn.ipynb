# %% [markdown]
# # Model #1 Univariate CNN (Forex Spot Price)
#
# * Import GBP_USD.csv
# * Using Forex Spot Price as input into an CNN model to predict Forex Spot Price of that currency pair.

# %% [markdown]
# # Imports

# %%
# Imports
# !pip install git+https://github.com/tensorflow/docs
import tensorflow as tf
print(tf.__version__)

# Libraries
import pathlib
import numpy as np
import pandas as pd
from numpy import array

# Plotting
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
plt.style.use('seaborn')
from matplotlib import rcParams

# Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, Flatten, Dropout
from numpy.random import seed
from random import shuffle

# Metric
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-9dko05fh
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-9dko05fh
# Requirement already satisfied: astor in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (49.6.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968_-cp36-none-any.whl size=146353 sha256=2745d119bc33759aa9fefa797a74e2c098eda8c78094c8b1355ae76602b1ee74
#   Stored in directory: /tmp/pip-ephem-wheel-cache-29cjgwqd/wheels/eb/1b/35/fce87697be00d2fc63e0b4b395b0d9c7e391a10e98d9a0d97f
# Successfully built tensorflow-docs
# Installing collected packages: tensorflow-docs
# Successfully installed tensorflow-docs-0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-
# 2.3.0

# %%
seed(1)
tf.random.set_seed(2)

# %% [markdown]
# # Data Collection

# %%
# Import forex dataset
forex_dataset= pd.read_csv('GBP_USD.csv', na_values = "?", comment='\t', skipinitialspace=True)
forex_dataset = forex_dataset.copy()
forex_dataset = forex_dataset.fillna(method='ffill')
forex_dataset = forex_dataset.iloc[::-1,:] # Reverse order of dataset
forex_dataset.reset_index(drop=True, inplace=True) #Reset index
dataset = pd.DataFrame(forex_dataset,columns=['Price','Date'])

# %% [markdown]
# ### Plotting Forex Spot Price before Normalisation

# %%
date = dataset['Date']
dateFormatting = pd.DataFrame({'new_date': pd.date_range('2019-12-31', '2020-07-31', periods=len(date))})
my_xticks = dateFormatting['new_date'].tolist()

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
price = np.array(dataset['Price'])
plt.plot_date(dates,price, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series Price of Forex Spot Price', size = 20)
plt.xlabel('Date')
plt.ylabel('Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# ### Plotting Features after Normalisation

# %%
price_frame = pd.DataFrame(np.concatenate([price]), columns= ["Price"])
scaler = MinMaxScaler(feature_range=(0,1))
normalisation_price = scaler.fit_transform(price_frame).reshape(-1,1)

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
plt.plot_date(dates, normalisation_price, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.gca().xaxis.set_major_formatter(date_format)
plt.title('Time Series of Forex Price', size = 20)
plt.ylabel('Normalisation between 0 and 1')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# # Splitting Data into Train, Validation & Test

# %%
new_dataset = normalisation_price

# %%
# Test, Validation, Train 
training_size = int(len(new_dataset)*0.80)
test_size = (len(new_dataset)-training_size)//2 # // Rounds down
train_data, valset_data, test_data = new_dataset[0:training_size], new_dataset[training_size:(training_size + test_size)],new_dataset[(training_size + test_size):]
print(train_data.shape)
print(valset_data.shape)
print(test_data.shape)
# Out:
# (171, 1)
# (21, 1)
# (22, 1)

# %%
# Start – Train
rcParams['figure.figsize'] = 15,6
plt.plot(train_data, label="Actual Train Dataset")
plt.title('Normalised Train Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# Middle – Validation
rcParams['figure.figsize'] = 15,6
plt.plot(valset_data, label="Actual Validation Dataset")
plt.title('Normalised Validation Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# End - Test
rcParams['figure.figsize'] = 15,6
plt.plot(test_data, label="Actual Test Dataset")
plt.title('Normalised Test Data', size =20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# # X_train, Y_train, X_test, Y_test
#
# *   time_step: previous days to consider before making prediction

# %%
# Convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
  dataX, dataY = [],[]
  # range: is the days in dataset - the days we need to consider - the 8th day
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step)]  # from i -> 6th day
    dataX.append(a) 
    y = dataset[i + time_step] # 7th day
    dataY.append(y)
  return np.array(dataX), np.array(dataY)

# %%
# Weekly_timestep means taking in 7 days of features at a time 
weekly_timestep = 7
X_train, Y_train = create_dataset(train_data, weekly_timestep)
X_val, Y_val = create_dataset(valset_data, weekly_timestep)
X_test, Y_test = create_dataset(test_data, weekly_timestep)

# %% [markdown]
# # Reshape for CNN

# %%
print('Before reshape')
print(X_train.shape), print(Y_train.shape)
print(X_val.shape), print(Y_val.shape)
print(X_test.shape), print(Y_test.shape)

X_train = X_train.reshape(163,7,1,1)
X_val = X_val.reshape(13,7,1,1)
X_test = X_test.reshape(14,7,1,1)

print('After reshape')
print(X_train.shape), print(Y_train.shape)
print(X_val.shape), print(Y_val.shape)
print(X_test.shape), print(Y_test.shape)
# Out:
# Before reshape
# (163, 7, 1)
# (163, 1)
# (13, 7, 1)
# (13, 1)
# (14, 7, 1)
# (14, 1)
# After reshape
# (163, 7, 1, 1)
# (163, 1)
# (13, 7, 1, 1)
# (13, 1)
# (14, 7, 1, 1)
# (14, 1)
# (None, None)

# %% [markdown]
# # CNN Model

# %%
def cnn_model(lr_rate, filters_layers, optimizer_one):

  opt = None
  if optimizer_one == 'adam':
   opt = keras.optimizers.Adam(learning_rate=lr_rate)
  elif optimizer_one == 'sgd':
   opt = keras.optimizers.SGD(learning_rate=lr_rate)
  else:
   opt = keras.optimizers.Adamax(learning_rate=lr_rate)

  cnn = Sequential([
    
  Conv2D(filters= filters_layers, input_shape=(7, 1, 1), kernel_size=(7,1), strides=1),
  Dropout(0.2),
  # Dense(64),
  Conv2D(filters= filters_layers, kernel_size=(1,1), strides=1),
  # Dropout(0.2),
  Dense(10), #
  Flatten(), # to make 1D
  Dense(1) # output feature map
  ])
  cnn.compile(loss = 'mean_squared_error', optimizer= opt)
  # print(cnn.summary())
  return cnn

# %% [markdown]
# ### Hyperparameter Tuning
# ![Grid Search & Random Search](https://miro.medium.com/max/1200/1*ZTlQm_WRcrNqL-nLnx6GJA.png)

# %%
# Function to create the best model for hyperparameters method
def bestModel(least_loss, learning_rate_list, optimizer_list, filter_list):
  for each_filter in filter_list:
    for each_optimizer in optimizer_list:
      for each_learning_rate in learning_rate_list:
        our_model = cnn_model(each_learning_rate, each_filter, each_optimizer)
        our_model.fit(X_train, Y_train, 
                validation_data= 
                (X_val, Y_val)
                , epochs=100,batch_size=10,verbose=1,
                callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)])
        loss = our_model.evaluate(X_test, Y_test)
        if loss < least_loss:
          least_loss = loss
          best_learning_rate = each_learning_rate
          best_optimizer = each_optimizer
          best_filter= each_filter
    return least_loss, best_learning_rate, best_optimizer, best_filter

# %% [markdown]
# #### Grid Search

# %%
filter_list = [15,30,10]
optimizer_list = ['adam', 'adamax']
learning_rate_list = [3e-3,3e-4]
least_loss_grid_search = 1

best_grid_search_model = bestModel(least_loss_grid_search, learning_rate_list, optimizer_list, filter_list)
print(best_grid_search_model)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 13ms/step - loss: 0.1468 - val_loss: 0.0045
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.0049
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0030
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0213 - val_loss: 0.0026
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0036
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0030
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0031
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0084
# Epoch 1/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0593 - val_loss: 0.0101
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0588 - val_loss: 0.0065
# Epoch 3/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0603 - val_loss: 0.0026
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0392 - val_loss: 0.0034
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0426 - val_loss: 0.0025
# Epoch 6/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0392 - val_loss: 0.0023
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0261 - val_loss: 0.0034
# Epoch 8/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0300 - val_loss: 0.0023
# Epoch 9/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0221 - val_loss: 0.0029
# 1/1 [==============================] - 0s 946us/step - loss: 0.0057
# Epoch 1/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0832 - val_loss: 0.0046
# Epoch 2/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0252 - val_loss: 0.0030
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0216 - val_loss: 0.0019
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0248 - val_loss: 0.0024
# Epoch 5/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0214 - val_loss: 0.0018
# Epoch 6/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0193 - val_loss: 0.0022
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0021
# Epoch 8/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0023
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0086
# Epoch 1/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3540 - val_loss: 0.1725
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2179 - val_loss: 0.0927
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1251 - val_loss: 0.0477
# Epoch 4/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0757 - val_loss: 0.0233
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0438 - val_loss: 0.0112
# Epoch 6/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0334 - val_loss: 0.0056
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0267 - val_loss: 0.0036
# Epoch 8/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0031
# Epoch 9/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.0029
# Epoch 10/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0246 - val_loss: 0.0029
# Epoch 11/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0253 - val_loss: 0.0029
# Epoch 12/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.0029
# Epoch 13/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0029
# Epoch 14/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0246 - val_loss: 0.0029
# Epoch 15/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0257 - val_loss: 0.0029
# Epoch 16/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0268 - val_loss: 0.0029
# Epoch 17/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0200 - val_loss: 0.0029
# Epoch 18/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.0029
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0121
# (0.005651602987200022, 0.0003, 'adam', 15)

# %% [markdown]
# #### Random Search

# %%
filter_list = [15,30,10]
# Seed random number generator
seed(len(filter_list))
# Prepare a sequence
filter_sequence = filter_list
print(filter_sequence) # Before Shuffle
# Randomly shuffle the sequence hidden layers
shuffle(filter_sequence) 
print(filter_sequence) # After Shuffle
# Out:
# [15, 30, 10]
# [10, 15, 30]

# %%
# Shuffling optimizers

optimizer_list = ['adam', 'adamax']
# Seed random number generator
seed(len(filter_sequence))
# Prepare a sequence
op_sequence = optimizer_list
print(op_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(op_sequence)
print(op_sequence) # After Shuffle
# Out:
# ['adam', 'adamax']
# ['adam', 'adamax']

# %%
# Shuffling learning rate

learning_rate_list = [3e-3,3e-4]
# Seed random number generator
seed(len(filter_sequence))
# Prepare a sequence
lr_sequence = learning_rate_list
print(lr_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(lr_sequence)
print(lr_sequence) # After Shuffle
# Out:
# [0.003, 0.0003]
# [0.0003, 0.003]

# %%
# Assigning least_loss
least_loss_random_search = 1

# %%
best_random_grid_model = bestModel(least_loss_random_search, lr_sequence, op_sequence, filter_sequence)
print(best_random_grid_model)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3050 - val_loss: 0.1307
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1794 - val_loss: 0.0509
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0807 - val_loss: 0.0145
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0473 - val_loss: 0.0044
# Epoch 5/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0352 - val_loss: 0.0030
# Epoch 6/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0030
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0282 - val_loss: 0.0032
# Epoch 8/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0417 - val_loss: 0.0033
# Epoch 9/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0030
# 1/1 [==============================] - 0s 903us/step - loss: 0.0101
# Epoch 1/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5429 - val_loss: 0.0532
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0655 - val_loss: 0.0023
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0261 - val_loss: 0.0023
# Epoch 4/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0241 - val_loss: 0.0043
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0023
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0154
# Epoch 1/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4414 - val_loss: 0.2196
# Epoch 2/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3138 - val_loss: 0.1387
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1892 - val_loss: 0.0842
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1246 - val_loss: 0.0500
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0898 - val_loss: 0.0280
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0732 - val_loss: 0.0148
# Epoch 7/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0508 - val_loss: 0.0085
# Epoch 8/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0498 - val_loss: 0.0055
# Epoch 9/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0517 - val_loss: 0.0041
# Epoch 10/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0367 - val_loss: 0.0037
# Epoch 11/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0378 - val_loss: 0.0036
# Epoch 12/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0360 - val_loss: 0.0036
# Epoch 13/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0499 - val_loss: 0.0035
# Epoch 14/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0393 - val_loss: 0.0035
# Epoch 15/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0384 - val_loss: 0.0035
# Epoch 16/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0317 - val_loss: 0.0035
# Epoch 17/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0035
# Epoch 18/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0359 - val_loss: 0.0034
# Epoch 19/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0441 - val_loss: 0.0034
# Epoch 20/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0378 - val_loss: 0.0034
# Epoch 21/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0443 - val_loss: 0.0034
# Epoch 22/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0396 - val_loss: 0.0033
# Epoch 23/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0391 - val_loss: 0.0033
# Epoch 24/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0342 - val_loss: 0.0033
# Epoch 25/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0364 - val_loss: 0.0033
# Epoch 26/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0335 - val_loss: 0.0033
# Epoch 27/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0315 - val_loss: 0.0033
# Epoch 28/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0328 - val_loss: 0.0033
# Epoch 29/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0034
# 1/1 [==============================] - 0s 916us/step - loss: 0.0130
# Epoch 1/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1630 - val_loss: 0.0082
# Epoch 2/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0478 - val_loss: 0.0052
# Epoch 3/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0420 - val_loss: 0.0037
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0397 - val_loss: 0.0040
# Epoch 5/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0285 - val_loss: 0.0041
# Epoch 6/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0320 - val_loss: 0.0037
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0169
# (0.010144546627998352, 0.0003, 'adam', 10)

# %% [markdown]
# #### Deciding on best hyperparameter results

# %%
# We want the smallest loss
# 0 = least loss, 1 = learning rate, 2 = optimizer, 3 = neurons
if best_grid_search_model[0] > best_random_grid_model[0]:
  best_learning_rate = best_random_grid_model[1]
  best_optimizer = best_random_grid_model[2]
  best_filter = best_random_grid_model[3]
else:
  best_learning_rate = best_grid_search_model[1]
  best_optimizer = best_grid_search_model[2]
  best_filter = best_grid_search_model[3]
print(best_learning_rate)
print(best_optimizer)
print(best_filter)
# Out:
# 0.0003
# adam
# 15

# %% [markdown]
# # Best Model Prediction

# %%
best_param_model = cnn_model(best_learning_rate, best_filter, best_optimizer)
best_param_model.fit(X_train, Y_train, epochs=150,batch_size=10,verbose=1)
loss = best_param_model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1002
# Epoch 2/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0578
# Epoch 3/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0524
# Epoch 4/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0502
# Epoch 5/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0493
# Epoch 6/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0418
# Epoch 7/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0382
# Epoch 8/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 9/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0363
# Epoch 10/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 11/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0299
# Epoch 12/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0259
# Epoch 13/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0267
# Epoch 14/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 15/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0250
# Epoch 16/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 17/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0202
# Epoch 18/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0261
# Epoch 19/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 20/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0188
# Epoch 21/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0197
# Epoch 22/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 23/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0200
# Epoch 24/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 25/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 26/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0190
# Epoch 27/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 28/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 29/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0173
# Epoch 30/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0161
# Epoch 31/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0167
# Epoch 32/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0164
# Epoch 33/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 34/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 35/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 36/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 37/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 38/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 39/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 40/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 41/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 42/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 43/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0107
# Epoch 44/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 45/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 46/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 47/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 48/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 49/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 50/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 51/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 52/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 53/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 54/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 55/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 56/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 57/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 58/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0095
# Epoch 59/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 60/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 61/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 62/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0095
# Epoch 63/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 64/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 65/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 66/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 67/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 68/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 69/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 70/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 71/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 72/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 73/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 74/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 75/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 76/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 77/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 78/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 79/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 80/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 81/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 82/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 83/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 84/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 85/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 86/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 87/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 88/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 89/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 90/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 91/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 92/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 93/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 94/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 95/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 96/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 97/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 98/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 99/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 100/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 101/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 102/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 103/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 104/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 105/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 106/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 107/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 108/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 109/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 110/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 111/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 112/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 113/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 114/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 115/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 116/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 117/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 118/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 119/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 120/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 121/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 122/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 123/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 124/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 125/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 126/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 127/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 128/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 129/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 130/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 131/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 132/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 133/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 134/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 135/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 136/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 137/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 138/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 139/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 140/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 141/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 142/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 143/150
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 144/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 145/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 146/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 147/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 148/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 149/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 150/150
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0050
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013

# %% [markdown]
# # Using best model to predict on X_train & X_test

# %%
# Prediction and check performance metric
train_predict = best_param_model.predict(X_train)
test_predict = best_param_model.predict(X_test)
print(train_predict.shape)
print(test_predict.shape)
# Out:
# (163, 1)
# (14, 1)

# %% [markdown]
# # Performance Metric

# %%
def get_performance_train (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_train, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_train, model_pred).round(4))
  print('R2_Score:',r2_score(Y_train, model_pred).round(4))

# %%
def get_performance_test (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_test, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_test, model_pred).round(4))  
  print('R2_Score:',r2_score(Y_test, model_pred).round(4))

# %%
print('Train:')
get_performance_train(train_predict)
print('\nTest:')
get_performance_test(test_predict)
# Out:
# Train:
# Mean Absolute Error: 0.0404
# Mean Squared Error: 0.0032
# R2_Score: 0.9301
#
# Test:
# Mean Absolute Error: 0.0263
# Mean Squared Error: 0.0013
# R2_Score: 0.8029

# %% [markdown]
# # Plotting Train Prediction, Validation & Test Prediction Versus Actual Data

# %%
# Transform back to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict =scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Train Predicted

# %%
look_back = 7

trainPredictPlot = np.empty_like(new_dataset) # shape
trainPredictPlot[:,:]= np.nan # values at 0
trainPredictPlot[look_back:len(train_predict)+look_back] = train_predict # Populates: 7 -> 162 + 7 = 169

trainPredictPlot = [item[0] for item in trainPredictPlot]
plt.plot(trainPredictPlot, label="train_predict_price")

train_panda = pd.DataFrame(train_data)
plt.plot(scaler.inverse_transform(train_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# ## Using last 7 days of training data to predict validation data.

# %%
# Taking the last 7 days of test
temp_input = train_data[-7:] # start, end 
temp_input
# Out:
# array([[0.59470124],
#        [0.62965051],
#        [0.62965051],
#        [0.62965051],
#        [0.61443067],
#        [0.60315671],
#        [0.52931229]])

# %%
# Demonstrate prediction for the next 4 as an example(but 21) days:

# Step 1. 7 days of feature = temp_input taken from the last 7 days of the training set
# Step 2  i is the day you are on and we want to predict 4 days: 0,1,2,3 (4 days)
# Step 3. Predict the 8th day on each of the 7 days,
# Step 4. Add this new predicted day to the list
# Step 5. Because we are now taking in the last 7 days + the new predicted value, the list is now size 8  
# Step 6. In order to take in 7 days at a time, we shift 1 to the right.
# Step 7. We reassign the X_train to the new 7 days
# Step 8. We predict the 8th day of the 7 days and continue the process
# Step 9. We then add the 8th day to the output list
# Step 10. We keep track of the 4 days by incrementing by i at the end-> i = i+1
# Step 11. Once we have predicted the 4 days, we return the list of 4 day values.

custom_day = len(valset_data)
lst_output=[]
n_steps=7
i=0
X_input = temp_input
# print(X_input)
while(i<custom_day):
  if(len(temp_input)>7):
    # print(temp_input)  
    X_input=array(temp_input[1:])
    # print("{} day input {}".format(i,X_input))
    # Correct input shape (1,7,3)
    X_input=X_input.reshape((1,n_steps,1, 1))
    # Prediction of X_input
    # print(X_input)
    Y_hat = best_param_model.predict(X_input)
    # print(Y_hat)
    temp_input = np.append(temp_input, Y_hat)
    temp_input=temp_input[1:]
    lst_output.append(Y_hat[0][0])
    i=i+1
  else:
    X_input=X_input.reshape((1,n_steps,1, 1))
    Y_hat = best_param_model.predict(X_input, verbose=0)
    # print(Y_hat)
    temp_input = np.append(temp_input, Y_hat)
    lst_output.append(Y_hat[0][0])
    i=i+1
print(lst_output)
# Out:
# [0.564402, 0.5515505, 0.5415287, 0.5473475, 0.5526728, 0.5519215, 0.5652648, 0.57120866, 0.5793181, 0.58988655, 0.5989054, 0.6071217, 0.6165268, 0.62393504, 0.63098997, 0.6374883, 0.64278996, 0.6472578, 0.6510655, 0.65384245, 0.65594876]

# %% [markdown]
# ## Plotting evaluation: Training Prediction of Validation Data

# %%
# Custom day plotted
day_new = custom_day-1

# Transform back to original value before normalised
custom_day_prediction = np.array(lst_output)
# print("Predicted validation:")
# print(custom_day_prediction)
plt.plot(custom_day_prediction, label="Predicted Validation Data")

# Transform back to original value before normalised
val_data = [item[0] for item in valset_data] 
custom_day_validation = val_data[:custom_day]
# print("Actual validation:")
# print(custom_day_validation)
plt.plot(custom_day_validation, label="Actual Validation Data")

rcParams['figure.figsize'] = 15,6
plt.title('Training Prediction of Validation Data', size = 20)
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Plot

# %%
look_back = 7

testPredictPlot = np.empty_like(new_dataset)
testPredictPlot[:,:]= np.nan
testPredictPlot[look_back:len(test_predict)+look_back] = test_predict
# 14 + (7*2) + 1 : 163 + 14 = test_predict
# 22:177 = test predict

testPredictPlot = [item[0] for item in testPredictPlot]
plt.plot(testPredictPlot, label="test_predict")

test_panda = pd.DataFrame(test_data)
plt.plot(scaler.inverse_transform(test_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train, test and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()
