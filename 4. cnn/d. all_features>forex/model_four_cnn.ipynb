# %% [markdown]
# # Model #4 Multivariate CNN (All features)
# * Import GBP/USD.csv, fuel_prices_com.csv & owid_covid_data.csv
# * Using COVID-19 Death Rates, Diesel Prices and Forex Spot Price as input into an CNN model to predict Forex Spot Price of the currency pair in question.

# %% [markdown]
# # Imports

# %%
# Imports
# !pip install git+https://github.com/tensorflow/docs
import tensorflow as tf
print(tf.__version__)

# Libraries
import pathlib
import numpy as np
import pandas as pd
from numpy import array

# Plotting
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
plt.style.use('seaborn')
from matplotlib import rcParams

# Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, Flatten, Dropout
from numpy.random import seed
from random import shuffle

# Metric
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-ovpmq87h
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-ovpmq87h
# Requirement already satisfied: astor in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (49.6.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968_-cp36-none-any.whl size=146353 sha256=0e003f842866aaa7407f7486dd8f6e65dc13941ddd482c869d0df80dc4a8e5d2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z8g1dh8g/wheels/eb/1b/35/fce87697be00d2fc63e0b4b395b0d9c7e391a10e98d9a0d97f
# Successfully built tensorflow-docs
# Installing collected packages: tensorflow-docs
# Successfully installed tensorflow-docs-0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-
# 2.3.0

# %%
seed(1)
tf.random.set_seed(2)

# %% [markdown]
# # Data Collection

# %%
# Importing covid_dataset
covid_dataset_data= pd.read_csv('owid_covid_data.csv', na_values = "?", comment='\t', skipinitialspace=True)
covid_dataset = covid_dataset_data.copy()
covid_dataset = covid_dataset.loc[covid_dataset.location=='United States', ['date', 'total_cases', 'total_deaths']]
covid_dataset.head()
# Out:
#              date  total_cases  total_deaths
# 32403  2019-12-31          0.0           0.0
# 32404  2020-01-01          0.0           0.0
# 32405  2020-01-02          0.0           0.0
# 32406  2020-01-03          0.0           0.0
# 32407  2020-01-04          0.0           0.0

# %%
# Import forex
forex_dataset_data= pd.read_csv('GBP_USD.csv', na_values = "?", comment='\t', skipinitialspace=True)
forex_dataset = forex_dataset_data.copy()
forex_dataset = forex_dataset.fillna(method='ffill')
forex_dataset = pd.DataFrame(forex_dataset,columns=['Price','Date'])

# %%
# Import price
fuel_dataset = pd.read_csv('fuel_prices_com.csv', encoding= 'unicode_escape')
fuel_dataset = fuel_dataset.loc[fuel_dataset.Country=='USA', ['Date','Diesel', 'Brent oil price']]

# %%
print(covid_dataset.shape), print(forex_dataset.shape),print(fuel_dataset.shape)
# Out:
# (218, 3)
# (214, 2)
# (29, 3)
# (None, None, None)

# %% [markdown]
# # Data Preprocessing / Data Cleaning & Collating
# *   We first isolate the date column both fuel_dataset and forex_dataset so that they are formatted in the same way.
# *   Challenge: Fuel Price dataset is a weekly timeseries dataset whereas Forex Price is a daily timeseries dataset.

# %%
fuel_dataset['Date'] = fuel_dataset['Date'].apply(lambda x: pd.to_datetime(str(x)))
fuel_dataset['Date'].head()
# Out:
# 772   2020-06-01
# 773   2020-01-13
# 774   2020-01-20
# 775   2020-01-27
# 776   2020-03-02
# Name: Date, dtype: datetime64[ns]

# %%
# We find out the format for where the day, month and year lie.
fuel_dataset["Date"] = pd.to_datetime(fuel_dataset["Date"], format="%d-%m-%Y")
forex_dataset["Date"] = pd.to_datetime(forex_dataset["Date"], format="%b %d, %Y")
# We transform these values to the same format.
fuel_dataset["Date"] = fuel_dataset["Date"].dt.strftime("%d-%m-%Y")
forex_dataset["Date"] = forex_dataset["Date"].dt.strftime("%d-%m-%Y")
# We then convert them back to a dataframe.
fuel_dataset["Date"] = pd.to_datetime(fuel_dataset["Date"], format="%d-%m-%Y")
forex_dataset["Date"] = pd.to_datetime(forex_dataset["Date"], format="%d-%m-%Y")

# %%
# We set the index for both datasets to be date.
forex_dataset.set_index("Date", inplace=True)
fuel_dataset.set_index("Date", inplace=True)
forex_dataset["Date"] = forex_dataset.index
fuel_dataset["date"] = fuel_dataset.index

# %%
# We then group these dates in a weekly period column
fuel_dataset["week"] = fuel_dataset.index.to_period('W')
forex_dataset["week"] = forex_dataset.index.to_period('W')

# %%
# We then join our datasets on the week column
data_ff = pd.merge(
    forex_dataset,
    fuel_dataset,
    left_on="week",
    right_on="week",
    how="left"
)

# %%
data_ff[data_ff.Diesel.isnull() | data_ff.Price.isnull()]
data_ff['Brent oil price'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 230    True
# 231    True
# 232    True
# 233    True
# 234    True
# Name: Brent oil price, Length: 235, dtype: bool

# %%
# We isolate the features that we want in our dataset
data_ff = pd.DataFrame(data_ff, columns = ['Date', 'Price', 'Diesel','Brent oil price']) 
# In order to merge with the next dataset we have to convert our Date frome from a datatime type to a string object.
data_ff['Date'] = data_ff['Date'].astype(str)

# %%
# We merge covid dataset with the forex + fuel dataset
data_ff = pd.merge(left=data_ff, left_on='Date',
         right=covid_dataset, right_on='date')

# %%
# Fill diesel with the mean 
data_ff = pd.DataFrame(data_ff, columns = ['Date', 'Price','total_deaths', 'total_cases','Diesel','Brent oil price']) 
data_ff['Diesel'].fillna((data_ff['Diesel'].mean()), inplace=True) # Notice how our dataset starts from the end rather than the top
data_ff['Brent oil price'].fillna((data_ff['Brent oil price'].mean()), inplace=True)
dataset = data_ff.iloc[::-1,:] # Reverse order of dataset
dataset.reset_index(drop=True, inplace=True) #Reset index

# %%
dataset = pd.DataFrame(dataset, columns = ['Date', 'Price', 'total_cases', 'total_deaths','Diesel','Brent oil price']) 
dataset
# Out:
#            Date   Price  total_cases  total_deaths   Diesel  Brent oil price
# 0    2019-12-31  1.3261          0.0           0.0  0.69532          42.1508
# 1    2020-01-01  1.3255          0.0           0.0  0.69532          42.1508
# 2    2020-01-02  1.3146          0.0           0.0  0.69532          42.1508
# 3    2020-01-03  1.3088          0.0           0.0  0.69532          42.1508
# 4    2020-01-04  1.3169          0.0           0.0  0.69532          42.1508
# ..          ...     ...          ...           ...      ...              ...
# 230  2020-07-27  1.2882    4234020.0      146935.0  0.69532          42.1508
# 231  2020-07-28  1.2932    4290263.0      148011.0  0.69532          42.1508
# 232  2020-07-29  1.2996    4351997.0      149256.0  0.69532          42.1508
# 233  2020-07-30  1.3095    4426982.0      150713.0  0.69532          42.1508
# 234  2020-07-31  1.3090    4495014.0      152070.0  0.69532          42.1508
#
# [235 rows x 6 columns]

# %% [markdown]
# # Plotting Features before Normalisation

# %% [markdown]
# ### Organising date for plotting

# %%
# Isolate date for plotting
date = dataset['Date']
# Isolate dates in question
dateFormatting = pd.DataFrame({'new_date': pd.date_range('2019-12-31', '2020-07-31', periods=len(date))})
# Convert date to list so that we can use the dates to plot on graph
my_xticks = dateFormatting['new_date'].tolist()

# %% [markdown]
# ### Plotting Forex Spot Price

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
price = np.array(dataset['Price'])
plt.plot_date(dates,price, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series Price of Forex Spot Price', size = 20)
plt.xlabel('Date')
plt.ylabel('Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# ### Plotting Diesel Prices

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
diesel = np.array(dataset['Diesel'])
plt.plot_date(dates,diesel, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series of Diesel Prices', size = 20)
plt.xlabel('Date')
plt.ylabel('Diesel Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# ### Plotting Accumulative Covid Deaths

# %%
# Adds the accumulative deaths every day of a country
total_deaths = dataset['total_deaths']
newDayDeaths = 0
daily_total_deaths = []
for dailyDeaths in total_deaths:
  newDayDeaths = dailyDeaths + newDayDeaths
  daily_total_deaths.append(newDayDeaths)

# %%
# Plots the accumulative daily death rates of a country
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
deaths = np.array(daily_total_deaths)
plt.plot_date(dates, deaths, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series of Total Deaths of Country', size = 20)
plt.xlabel('Date')
plt.ylabel('Total Deaths')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# # Plotting Features after Normalisation

# %%
price_frame = pd.DataFrame(np.concatenate([price]), columns= ["Price"])
death_frame = pd.DataFrame(np.concatenate([daily_total_deaths]), columns= ["Total_Deaths_US"])
diesel_frame = pd.DataFrame(np.concatenate([diesel]), columns= ["Diesel"])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
normalisation_us_deaths = scaler.fit_transform(death_frame).reshape(-1,1)
normalisation_price = scaler.fit_transform(price_frame).reshape(-1,1)
normalisation_diesel_price = scaler.fit_transform(diesel_frame).reshape(-1,1)

# %%
rcParams['figure.figsize'] = 15,6
plt.plot(normalisation_us_deaths,label="Covid Death Rates")
plt.plot(normalisation_price, label="Spot Price")
plt.plot(normalisation_diesel_price, label="Diesel Price")
dates = np.array(dateFormatting['new_date'])
plt.title('Time Series of Deaths Rates, Diesel Prices & Forex Price', size = 20)
plt.ylabel('Normalisation between 0 and 1')
plt.xlabel('Days')
plt.legend() 
plt.show()

# %% [markdown]
# # Splitting Data into Train, Validation & Test

# %%
new_dataset = np.hstack((normalisation_us_deaths, normalisation_diesel_price, normalisation_price))

# %%
# Test, Validation, Train 
training_size = int(len(new_dataset)*0.80)
test_size = (len(new_dataset)-training_size)//2 # // Rounds down
train_data, valset_data, test_data = new_dataset[0:training_size], new_dataset[training_size:(training_size + test_size)],new_dataset[(training_size + test_size):]
print(train_data.shape)
print(valset_data.shape)
print(test_data.shape)
# Out:
# (188, 3)
# (23, 3)
# (24, 3)

# %%
# Start – Train
rcParams['figure.figsize'] = 15,6
plt.plot(train_data, label="Actual Train Dataset")
plt.title('Normalised Train Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# Middle – Validation
rcParams['figure.figsize'] = 15,6
plt.plot(valset_data, label="Actual validation dataset")
plt.title('Normalised Validation Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# End - Test
rcParams['figure.figsize'] = 15,6
plt.plot(test_data, label="Actual test dataset")
plt.title('Normalised Test Data', size =20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# # X_train, Y_train, X_test, Y_test

# %%
# Convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
  dataX, dataY = [],[]
  # range: is the days in dataset - the days we need to consider - the 8th day
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step)]  # from i -> 6th day
    dataX.append(a) 
    y = dataset[i + time_step][2] # 7th day
    dataY.append(y)
  return np.array(dataX), np.array(dataY)

# %%
# Weekly_timestep means taking in 7 days of features at a time 
weekly_timestep = 7
X_train, Y_train = create_dataset(train_data, weekly_timestep)
X_val, Y_val = create_dataset(valset_data, weekly_timestep)
X_test, Y_test = create_dataset(test_data, weekly_timestep)

# %% [markdown]
# ## Data Augmentation

# %%
reversed_x_train = X_train[::-1]
reversed_y_train = Y_train[::-1]
reversed_x_val = X_val[::-1]
reversed_y_val = Y_val[::-1]

new_X_train = np.concatenate((X_train, reversed_x_train))
new_Y_train = np.concatenate((Y_train, reversed_y_train))
new_X_val = np.concatenate((X_val, reversed_x_val))
new_Y_val = np.concatenate((Y_val, reversed_y_val))
print(len(new_X_train))
print(len(new_Y_train))
print(len(new_X_val)) 
print(len(new_Y_val))
# Out:
# 360
# 360
# 30
# 30

# %% [markdown]
# # Reshape for CNN

# %%
print('Before reshape')
print(X_train.shape), print(Y_train.shape)
print(X_val.shape), print(Y_val.shape)
print(X_test.shape), print(Y_test.shape)

X_train = X_train.reshape(180,7,3,1)
X_val = X_val.reshape(15,7,3,1)
X_test = X_test.reshape(16,7,3,1)

print('After reshape')
print(X_train.shape), print(Y_train.shape)
print(X_val.shape), print(Y_val.shape)
print(X_test.shape), print(Y_test.shape)
# Out:
# Before reshape
# (180, 7, 3)
# (180,)
# (15, 7, 3)
# (15,)
# (16, 7, 3)
# (16,)
# After reshape
# (180, 7, 3, 1)
# (180,)
# (15, 7, 3, 1)
# (15,)
# (16, 7, 3, 1)
# (16,)
# (None, None)

# %% [markdown]
# # CNN Model

# %%
def cnn_model(lr_rate, filters_layers, optimizer_one):

  opt = None
  if optimizer_one == 'adam':
   opt = keras.optimizers.Adam(learning_rate=lr_rate)
  elif optimizer_one == 'sgd':
   opt = keras.optimizers.SGD(learning_rate=lr_rate)
  else:
   opt = keras.optimizers.Adamax(learning_rate=lr_rate)

  cnn = Sequential([
    
  Conv2D(filters= filters_layers, input_shape=(7, 3, 1), kernel_size=(7,1), strides=1),
  Dropout(0.2),
  # Dense(64),
  Conv2D(filters= filters_layers, kernel_size=(1,1), strides=1),
  # Dropout(0.2),
  # Dense(10), #
  Flatten(), # to make 1D
  Dense(1) # output feature map
  ])
  cnn.compile(loss = 'mean_squared_error', optimizer= opt)
  # print(cnn.summary())
  return cnn

# %% [markdown]
# ## Hyperparameter Tuning
# ![Grid Search & Random Search](https://miro.medium.com/max/1200/1*ZTlQm_WRcrNqL-nLnx6GJA.png)

# %%
# Function to create the best model for hyperparameters method
def bestModel(least_loss, learning_rate_list, optimizer_list, filter_list):
  for each_filter in filter_list:
    for each_optimizer in optimizer_list:
      for each_learning_rate in learning_rate_list:
        our_model = cnn_model(each_learning_rate, each_filter, each_optimizer)
        our_model.fit(X_train, Y_train, 
                validation_data= 
                (X_val, Y_val)
                , epochs=100,batch_size=10,verbose=1,
                callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)])
        loss = our_model.evaluate(X_test, Y_test)
        if loss < least_loss:
          least_loss = loss
          best_learning_rate = each_learning_rate
          best_optimizer = each_optimizer
          best_filter= each_filter
    return least_loss, best_learning_rate, best_optimizer, best_filter

# %% [markdown]
# ### Grid Search

# %%
filter_list = [15,30,10]
optimizer_list = ['adam', 'adamax']
learning_rate_list = [3e-3,3e-4]
least_loss_grid_search = 1

best_grid_search_model = bestModel(least_loss_grid_search, learning_rate_list, optimizer_list, filter_list)
print(best_grid_search_model)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1403 - val_loss: 0.0147
# Epoch 2/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0374 - val_loss: 0.0079
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0258 - val_loss: 0.0028
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0210 - val_loss: 0.0024
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0032
# Epoch 6/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0163 - val_loss: 0.0022
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0147 - val_loss: 0.0036
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0029
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.0022
# Epoch 10/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0132 - val_loss: 0.0022
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0040
# Epoch 12/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0126 - val_loss: 0.0031
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0025
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0060
# Epoch 1/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.9906 - val_loss: 0.4912
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6582 - val_loss: 0.3279
# Epoch 3/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4461 - val_loss: 0.2034
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2820 - val_loss: 0.1163
# Epoch 5/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1592 - val_loss: 0.0579
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1028 - val_loss: 0.0236
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0642 - val_loss: 0.0093
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.0044
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0506 - val_loss: 0.0033
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0468 - val_loss: 0.0022
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0492 - val_loss: 0.0023
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0426 - val_loss: 0.0021
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0488 - val_loss: 0.0022
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0459 - val_loss: 0.0025
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0532 - val_loss: 0.0026
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 1/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1960 - val_loss: 0.0054
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0382 - val_loss: 0.0043
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0284 - val_loss: 0.0033
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0263 - val_loss: 0.0023
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0277 - val_loss: 0.0023
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0225 - val_loss: 0.0023
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0212 - val_loss: 0.0024
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0195 - val_loss: 0.0022
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.0023
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0251 - val_loss: 0.0021
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0202 - val_loss: 0.0021
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0208 - val_loss: 0.0021
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0020
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0020
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0201 - val_loss: 0.0019
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0169 - val_loss: 0.0019
# Epoch 17/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0018
# Epoch 18/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0019
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0018
# Epoch 20/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0171 - val_loss: 0.0019
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0102
# Epoch 1/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5552 - val_loss: 0.0151
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3689 - val_loss: 0.0020
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2689 - val_loss: 0.0081
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1937 - val_loss: 0.0271
# Epoch 5/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.1343 - val_loss: 0.0489
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0100
# (0.006015538237988949, 0.003, 'adam', 15)

# %% [markdown]
# ### Random Search

# %%
# Shuffle filters

filter_list = [15,30,10]
# Seed random number generator
seed(len(filter_list))
# Prepare a sequence
filter_sequence = filter_list
print(filter_sequence) # Before Shuffle
# Randomly shuffle the sequence hidden layers
shuffle(filter_sequence) 
print(filter_sequence) # After Shuffle
# Out:
# [15, 30, 10]
# [10, 15, 30]

# %%
# Shuffling optimizers

optimizer_list = ['adam', 'adamax']
# Seed random number generator
seed(len(filter_sequence))
# Prepare a sequence
op_sequence = optimizer_list
print(op_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(op_sequence)
print(op_sequence) # After Shuffle
# Out:
# ['adam', 'adamax']
# ['adamax', 'adam']

# %%
# Shuffling learning rate

learning_rate_list = [3e-3,3e-4]
# Seed random number generator
seed(len(filter_sequence))
# Prepare a sequence
lr_sequence = learning_rate_list
print(lr_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(lr_sequence)
print(lr_sequence) # After Shuffle
# Out:
# [0.003, 0.0003]
# [0.0003, 0.003]

# %%
# Assigning least_loss
least_loss_random_search = 1

# %%
best_random_grid_model = bestModel(least_loss_random_search, lr_sequence, op_sequence, filter_sequence)
print(best_random_grid_model)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3082 - val_loss: 0.0037
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2175 - val_loss: 0.0030
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1557 - val_loss: 0.0086
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0952 - val_loss: 0.0172
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0787 - val_loss: 0.0246
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 1/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2050 - val_loss: 0.1136
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0312 - val_loss: 0.0516
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0298 - val_loss: 0.0430
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0337
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0263 - val_loss: 0.0259
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0259 - val_loss: 0.0141
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0220 - val_loss: 0.0120
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0213 - val_loss: 0.0101
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0246 - val_loss: 0.0058
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0211 - val_loss: 0.0054
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0058
# Epoch 12/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0215 - val_loss: 0.0041
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0050
# Epoch 14/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0053
# Epoch 15/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0168 - val_loss: 0.0039
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0032
# Epoch 17/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0164 - val_loss: 0.0028
# Epoch 18/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0026
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0197 - val_loss: 0.0026
# Epoch 20/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0146 - val_loss: 0.0023
# Epoch 21/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0026
# Epoch 22/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0023
# Epoch 23/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0025
# Epoch 24/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0024
# Epoch 25/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0025
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0117
# Epoch 1/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6424 - val_loss: 0.3265
# Epoch 2/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4391 - val_loss: 0.2015
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3039 - val_loss: 0.1127
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.2016 - val_loss: 0.0545
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.1372 - val_loss: 0.0222
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0891 - val_loss: 0.0076
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0761 - val_loss: 0.0031
# Epoch 8/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0573 - val_loss: 0.0031
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0526 - val_loss: 0.0046
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0530 - val_loss: 0.0050
# Epoch 11/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0511 - val_loss: 0.0054
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 1/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2553 - val_loss: 0.1340
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0469 - val_loss: 0.0034
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0241 - val_loss: 0.0056
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.0017
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0241 - val_loss: 0.0017
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.0033
# Epoch 7/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0179 - val_loss: 0.0017
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0193
# (0.0055191549472510815, 0.0003, 'adamax', 10)

# %% [markdown]
# #### Deciding on best hyperparameter results

# %%
# We want the smallest loss
# 0 = least loss, 1 = learning rate, 2 = optimizer, 3 = neurons
if best_grid_search_model[0] > best_random_grid_model[0]:
  best_learning_rate = best_random_grid_model[1]
  best_optimizer = best_random_grid_model[2]
  best_filter = best_random_grid_model[3]
else:
  best_learning_rate = best_grid_search_model[1]
  best_optimizer = best_grid_search_model[2]
  best_filter = best_grid_search_model[3]
print(best_learning_rate)
print(best_optimizer)
print(best_filter)
# Out:
# 0.0003
# adamax
# 10

# %% [markdown]
# # Best Model Prediction

# %%
best_param_model = cnn_model(best_learning_rate, best_filter, best_optimizer)
best_param_model.fit(X_train, Y_train, epochs=150,batch_size=10,verbose=1)
loss = best_param_model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4625
# Epoch 2/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3128
# Epoch 3/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2698
# Epoch 4/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1906
# Epoch 5/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1721
# Epoch 6/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1345
# Epoch 7/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1292
# Epoch 8/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1068
# Epoch 9/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0831
# Epoch 10/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0818
# Epoch 11/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0858
# Epoch 12/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0761
# Epoch 13/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0783
# Epoch 14/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0814
# Epoch 15/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0790
# Epoch 16/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0669
# Epoch 17/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0782
# Epoch 18/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0789
# Epoch 19/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0737
# Epoch 20/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0718
# Epoch 21/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0720
# Epoch 22/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0607
# Epoch 23/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0666
# Epoch 24/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0699
# Epoch 25/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0571
# Epoch 26/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0547
# Epoch 27/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 28/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0550
# Epoch 29/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0568
# Epoch 30/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0513
# Epoch 31/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0541
# Epoch 32/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0475
# Epoch 33/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0517
# Epoch 34/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0533
# Epoch 35/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0593
# Epoch 36/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0491
# Epoch 37/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0508
# Epoch 38/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0483
# Epoch 39/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0413
# Epoch 40/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0482
# Epoch 41/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0492
# Epoch 42/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0431
# Epoch 43/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0447
# Epoch 44/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0446
# Epoch 45/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0460
# Epoch 46/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0426
# Epoch 47/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 48/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0409
# Epoch 49/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0374
# Epoch 50/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0365
# Epoch 51/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 52/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 53/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0338
# Epoch 54/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0371
# Epoch 55/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0384
# Epoch 56/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0410
# Epoch 57/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0369
# Epoch 58/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0368
# Epoch 59/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 60/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0326
# Epoch 61/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0338
# Epoch 62/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 63/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0309
# Epoch 64/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0327
# Epoch 65/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0286
# Epoch 66/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0322
# Epoch 67/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0296
# Epoch 68/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0306
# Epoch 69/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0309
# Epoch 70/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0294
# Epoch 71/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 72/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0298
# Epoch 73/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0308
# Epoch 74/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0285
# Epoch 75/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 76/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0321
# Epoch 77/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 78/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0291
# Epoch 79/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0285
# Epoch 80/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0317
# Epoch 81/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 82/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0256
# Epoch 83/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 84/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 85/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0309
# Epoch 86/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 87/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 88/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 89/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0272
# Epoch 90/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0258
# Epoch 91/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 92/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0238
# Epoch 93/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0261
# Epoch 94/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0227
# Epoch 95/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0262
# Epoch 96/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0222
# Epoch 97/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0258
# Epoch 98/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0224
# Epoch 99/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 100/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0262
# Epoch 101/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 102/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 103/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 104/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0224
# Epoch 105/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0222
# Epoch 106/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 107/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 108/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 109/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 110/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 111/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 112/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0216
# Epoch 113/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0217
# Epoch 114/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0227
# Epoch 115/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 116/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 117/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 118/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0224
# Epoch 119/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0200
# Epoch 120/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0178
# Epoch 121/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 122/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0202
# Epoch 123/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 124/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 125/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 126/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 127/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 128/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0199
# Epoch 129/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0211
# Epoch 130/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0183
# Epoch 131/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0199
# Epoch 132/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0208
# Epoch 133/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0217
# Epoch 134/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 135/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 136/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 137/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 138/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 139/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 140/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 141/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 142/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0180
# Epoch 143/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 144/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 145/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 146/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 147/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 148/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 149/150
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0142
# Epoch 150/150
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0181
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0244

# %% [markdown]
# # Using best model to predict on X_train & X_test

# %%
# Prediction and check performance metric
train_predict = best_param_model.predict(X_train)
test_predict = best_param_model.predict(X_test)
print(train_predict.shape)
print(test_predict.shape)
# Out:
# (180, 1)
# (16, 1)

# %% [markdown]
# # Performance Metric

# %%
def get_performance_train (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_train, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_train, model_pred).round(4))
  print('R2_Score:',r2_score(Y_train, model_pred).round(4))

# %%
def get_performance_test (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_test, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_test, model_pred).round(4))  
  print('R2_Score:',r2_score(Y_test, model_pred).round(4))

# %%
print('Train:')
get_performance_train(train_predict)
print('\nTest:')
get_performance_test(test_predict)
# Out:
# Train:
# Mean Absolute Error: 0.0686
# Mean Squared Error: 0.0103
# R2_Score: 0.7587
#
# Test:
# Mean Absolute Error: 0.1455
# Mean Squared Error: 0.0244
# R2_Score: -2.1893

# %% [markdown]
# # Plotting Train Prediction, Validation & Test Prediction Versus Actual Data

# %%
# Transform back to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict =scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Train Predicted

# %%
look_back = 7

trainPredictPlot = np.empty_like(new_dataset) # shape
trainPredictPlot[:,:]= np.nan # values 0
trainPredictPlot[look_back:len(train_predict)+look_back] = train_predict # Populates: 7 -> 162 + 7 = 169

trainPredictPlot = [item[2] for item in trainPredictPlot]
plt.plot(trainPredictPlot, label="train_predict_price")

train_panda = pd.DataFrame(train_data)
plt.plot(scaler.inverse_transform(train_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# ## Using last 7 days of training data to predict validation data.

# %%
temp_input = train_data[-7:]

# %%
# Demonstrate prediction for the next e.g.4 days:

# Step 1. 7 days of feature = temp_input taken from the last 7 days of the training set
# Step 2  i is the day you are on and we want to predict 4 days: 0,1,2,3 (4 days)
# Step 3. Predict the 8th day on each of the 7 days,
# Step 4. Add this new predicted day to the list
# Step 5. Because we are now taking in the last 7 days + the new predicted value, the list is now size 8  
# Step 6. In order to take in 7 days at a time, we shift 1 to the right.
# Step 7. We reassign the X_train to the new 7 days
# Step 8. We predict the 8th day of the 7 days and continue the process
# Step 9. We then add the 8th day to the output list
# Step 10. We keep track of the 4 days by incrementing by i at the end-> i = i+1
# Step 11. Once we have predicted the 4 days, we return the list of 4 day values.


custom_day = len(valset_data)
lst_output=[]
n_steps=7
i=0
X_input = temp_input
while(i<custom_day):
  if(len(temp_input)>7):
    X_input=array(temp_input[1:])
    X_input=X_input.reshape((1,n_steps,3, 1))
    Y_hat = best_param_model.predict(X_input)
    temp_input = np.append(temp_input, Y_hat)
    temp_input=temp_input[1:]
    lst_output.append(Y_hat[0][0])
    i=i+1
  else:
    X_input=X_input.reshape((1,n_steps,3, 1))
    Y_hat = best_param_model.predict(X_input, verbose=0)
    temp_input = np.append(temp_input, Y_hat)
    lst_output.append(Y_hat[0][0])
    i=i+1
print(lst_output)
# Out:
# [0.6062081, 0.6113395, 0.53647476, 0.6153177, 0.6242632, 0.5912233, 0.6024224, 0.6344822, 0.59811956, 0.60176873, 0.6272673, 0.6371728, 0.61386025, 0.621552, 0.63515806, 0.6414816, 0.6527982, 0.6578248, 0.6593172, 0.6491016, 0.657323, 0.6644309, 0.6637013]

# %% [markdown]
# ## Plotting evaluation: Training Prediction of Validation Data

# %%
day_new = custom_day-1

# Predicted 21 days from training
# Transform back to original value before normalised
custom_day_prediction = np.array(lst_output)
# print("Predicted validation:")
# print(custom_day_prediction)
plt.plot(custom_day_prediction, label="Predicted Validation Data")

# Transform back to original value before normalised
val_data = [item[2] for item in valset_data] 
custom_day_validation = val_data[:custom_day]
# print("Actual validation:")
# print(custom_day_validation)
plt.plot(custom_day_validation, label="Actual Validation Data")

# Information
rcParams['figure.figsize'] = 15,6
plt.title('Training Prediction of Validation Data', size = 20)
plt.xlabel('Days predicted')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Plot

# %%
look_back = 7

testPredictPlot = np.empty_like(new_dataset)
testPredictPlot[:,:]= np.nan
testPredictPlot[look_back:len(test_predict)+look_back] = test_predict
testPredictPlot = [item[0] for item in testPredictPlot]
plt.plot(testPredictPlot, label="test_predict")

test_panda = pd.DataFrame(test_data)
plt.plot(scaler.inverse_transform(test_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train, test and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()
