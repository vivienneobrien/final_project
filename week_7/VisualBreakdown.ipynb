# %%
# !pip install quandl
import quandl
import numpy as np

# %%
quandl.ApiConfig.api_key = 'oJL3wNsrZcULBLacB-Mx'

# Base is $ 
# To the £
data = quandl.get("BOE/XUDLDSY")
print(data)
# Out:
#              Value
# Date
# 1979-01-02  2.0264
# 1979-01-03  2.0028
# 1979-01-04  1.9965
# 1979-01-05  1.9957
# 1979-01-08  1.9998
# ...            ...
# 2020-07-10  1.2686
# 2020-07-13  1.2644
# 2020-07-14  1.2556
# 2020-07-15  1.2648
# 2020-07-16  1.2623
#
# [10503 rows x 1 columns]

# %%
# Isolate the dates you want to view i.e. December- Current
data = quandl.get("BOE/XUDLDSY", start_date="2019-01-01", end_date="2020-07-01")
print(data)
# Out:
#              Value
# Date
# 2019-01-02  1.2827
# 2019-01-03  1.2813
# 2019-01-04  1.2944
# 2019-01-07  1.2993
# 2019-01-08  1.2953
# ...            ...
# 2020-06-25  1.2429
# 2020-06-26  1.2341
# 2020-06-29  1.2290
# 2020-06-30  1.2382
# 2020-07-01  1.2481
#
# [380 rows x 1 columns]

# %%
import requests  # Import the requests library
# global: https://covid2019-api.herokuapp.com/v2/timeseries/global global deaths and confirmed cases from 1/22/20
# Deals with countries daily
# Query URL –> Ideal dataset but only does one day dataset
url = ('https://covid2019-api.herokuapp.com/v2/deaths')
# Query URL
url = ('https://api.covid19api.com/summary'
       )
# Some api's will have nicer syntax like:
# `&time=2010..2012` or `&na_item=B1GQ,D21`
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
payload = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(payload)
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely
# Out:
# https://api.covid19api.com/summary
# Request returned 200 : 'OK'
# {'Countries': [{'Country': 'Afghanistan',
#                 'CountryCode': 'AF',
#                 'Date': '2020-07-19T13:41:44Z',
#                 'NewConfirmed': 72,
#                 'NewDeaths': 17,
#                 'NewRecovered': 122,
#                 'Premium': {},
#                 'Slug': 'afghanistan',
#                 'TotalConfirmed': 35301,
#                 'TotalDeaths': 1164,
#                 'TotalRecovered': 23273},
#                {'Country': 'Albania',
#                 'CountryCode': 'AL',
#                 'Date': '2020-07-19T13:41:44Z',
#                 'NewConfirmed': 102,
#                 'NewDeaths': 4,
#                 'NewRecovered': 50,
#                 'Premium': {},
#                 'Slug': 'albania',
#                 'TotalConfirmed': 4008,
#                 'TotalDeaths': 111,
#                 'TotalRecovered': 2264},
#                {'Country': 'Algeria',
# ...

# %%
# Accumulative USA & British Death Rates

import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 20))

def f(x):
    return np.sin(x) - x * np.cos(x)

def fp(x):
    """ The derivative of f """
    return x * np.sin(x)

X = [1,2,3,4]
my_xticks = ['01/01/20','02/01/20','33/02/20','11/03/20'] 

fig, ax = plt.subplots(1, sharex='col', sharey='row', figsize=(10,5))
fig.subplots_adjust(hspace=.99)

ax.plot(f(X))
ax.set_xticks(X)
ax.set_xticklabels(my_xticks, fontsize=12)
ax.set(xlabel='X Values', ylabel='Price',
       title='Accumulative USA & British Death Rates')



plt.show()

# %%
# USA Death Rates

import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.sin(x) - x * np.cos(x)

def fp(x):
    """ The derivative of f """
    return x * np.sin(x)

X = [1,2,3,4]
my_xticks = ['01/01/20','02/01/20','33/02/20','11/03/20'] 

fig, ax = plt.subplots(1, 
           sharex='col', sharey='row', figsize=(10,5))
fig.subplots_adjust(hspace=.99)

ax.plot(x, f(X))
ax.set_xticks(X)
ax.set_xticklabels(my_xticks, fontsize=12)
ax.set(xlabel='X Values', ylabel='Price',
       title='USA Death Rates')

plt.show()

# %%
# UK Death Rates

import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 20))

def f(x):
    return np.sin(x) - x * np.cos(x)

def fp(x):
    """ The derivative of f """
    return x * np.sin(x)

X = [1,2,3,4]
my_xticks = ['01/01/20','02/01/20','33/02/20','11/03/20'] 

fig, ax = plt.subplots(1, 
           sharex='col', sharey='row', figsize=(10,5))
fig.subplots_adjust(hspace=.99)

ax.plot(x, f(X))
ax.set_xticks(X)
ax.set_xticklabels(my_xticks, fontsize=12)
ax.set(xlabel='X Values', ylabel='Price',
       title='British Death Rates')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,1,2,3])
y = np.array([20,21,22,23])
my_xticks = ['01/01/20','02/01/20','33/02/20','11/03/20'] 
plt.xticks(x, my_xticks)
plt.plot(x, y)
plt.show()
