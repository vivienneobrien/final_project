# %% [markdown]
# # Model #1 Univariate LSTM (Forex Spot Price)
#
# * Import GBP_USD.csv
# * Using Forex Spot Price as input into an LSTM model to predict Forex Spot Price of that currency pair.

# %% [markdown]
# # Imports

# %%
# Imports
# !pip install git+https://github.com/tensorflow/docs
import tensorflow as tf
print(tf.__version__)

# Libraries
import pathlib
import numpy as np
import pandas as pd
from numpy import array

# Plotting
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
plt.style.use('seaborn')
from matplotlib import rcParams

# Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer, Dense, LSTM, Dropout
from numpy.random import seed
from random import shuffle

# Metric
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-bx1n7pvn
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-bx1n7pvn
# Requirement already satisfied (use --upgrade to upgrade): tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968- from git+https://github.com/tensorflow/docs in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: astor in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (49.6.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968_-cp36-none-any.whl size=146353 sha256=3559f8f1cd80e94ef436ca0352ac52d435a8958a2216e19cca848bb1aac631f2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n7zjp2dj/wheels/eb/1b/35/fce87697be00d2fc63e0b4b395b0d9c7e391a10e98d9a0d97f
# Successfully built tensorflow-docs
# 2.3.0

# %%
seed(1)
tf.random.set_seed(2)

# %% [markdown]
# # Data Collection

# %%
# Import forex dataset
forex_dataset= pd.read_csv('GBP_USD.csv', na_values = "?", comment='\t', skipinitialspace=True)
forex_dataset = forex_dataset.copy()
forex_dataset = forex_dataset.fillna(method='ffill')
forex_dataset = forex_dataset.iloc[::-1,:] # Reverse order of dataset
forex_dataset.reset_index(drop=True, inplace=True) #Reset index
dataset = pd.DataFrame(forex_dataset,columns=['Price','Date'])

# %%
dataset.head()
# Out:
#     Price          Date
# 0  1.3261  Dec 31, 2019
# 1  1.3255  Jan 01, 2020
# 2  1.3146  Jan 02, 2020
# 3  1.3088  Jan 03, 2020
# 4  1.3169  Jan 04, 2020

# %% [markdown]
# ### Plotting Forex Spot Price before Normalisation

# %%
date = dataset['Date']
dateFormatting = pd.DataFrame({'new_date': pd.date_range('2019-12-31', '2020-07-31', periods=len(date))})
my_xticks = dateFormatting['new_date'].tolist()

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
price = np.array(dataset['Price'])
plt.plot_date(dates,price, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series Price of Forex Spot Price', size = 20)
plt.xlabel('Date')
plt.ylabel('Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# ### Plotting Features after Normalisation

# %%
price_frame = pd.DataFrame(np.concatenate([price]), columns= ["Price"])
scaler = MinMaxScaler(feature_range=(0,1))
normalisation_price = scaler.fit_transform(price_frame).reshape(-1,1)

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
plt.plot_date(dates, normalisation_price, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.gca().xaxis.set_major_formatter(date_format)
plt.title('Time Series of Forex Price', size = 20)
plt.ylabel('Normalisation between 0 and 1')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# # Splitting Data into Train, Validation & Test

# %%
new_dataset = normalisation_price

# %%
# Test, Validation, Train 
training_size = int(len(new_dataset)*0.80)
test_size = (len(new_dataset)-training_size)//2 # // Rounds down
train_data, valset_data, test_data = new_dataset[0:training_size], new_dataset[training_size:(training_size + test_size)],new_dataset[(training_size + test_size):]
print(train_data.shape)
print(valset_data.shape)
print(test_data.shape)
# Out:
# (171, 1)
# (21, 1)
# (22, 1)

# %%
# Start – Train
rcParams['figure.figsize'] = 15,6
plt.plot(train_data, label="Actual Train Dataset")
plt.title('Normalised Train Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# Middle – Validation
rcParams['figure.figsize'] = 15,6
plt.plot(valset_data, label="Actual Validation Dataset")
plt.title('Normalised Validation Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# End - Test
rcParams['figure.figsize'] = 15,6
plt.plot(test_data, label="Actual Test Dataset")
plt.title('Normalised Test Data', size =20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# # X_train, Y_train, X_test, Y_test
#
# *   time_step: previous days to consider before making prediction

# %%
# Convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
  dataX, dataY = [],[]
  # range: is the days in dataset - the days we need to consider - the 8th day
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step)]  # from i -> 6th day
    dataX.append(a) 
    y = dataset[i + time_step] # 7th day
    dataY.append(y)
  return np.array(dataX), np.array(dataY)

# %%
# Weekly_timestep means taking in 7 days of features at a time 
weekly_timestep = 7
X_train, Y_train = create_dataset(train_data, weekly_timestep)
X_val, Y_val = create_dataset(valset_data, weekly_timestep)
X_test, Y_test = create_dataset(test_data, weekly_timestep)

# %% [markdown]
# ## Data Augmentation

# %%
reversed_x_train = X_train[::-1]
reversed_y_train = Y_train[::-1]
reversed_x_val = X_val[::-1]
reversed_y_val = Y_val[::-1]

new_X_train = np.concatenate((X_train, reversed_x_train))
new_Y_train = np.concatenate((Y_train, reversed_y_train))
new_X_val = np.concatenate((X_val, reversed_x_val))
new_Y_val = np.concatenate((Y_val, reversed_y_val))
print(len(new_X_train))
print(len(new_Y_train))
print(len(new_X_val)) 
print(len(new_Y_val))
# Out:
# 326
# 326
# 26
# 26

# %% [markdown]
# # Stacked LSTM Model

# %%
def lstm_model(lr_rate, neuron_layer, optimizer_one):
  model = Sequential()
  opt = None
  if optimizer_one == 'adam':
   opt = keras.optimizers.Adam(learning_rate=lr_rate)
  elif optimizer_one == 'sgd':
   opt = keras.optimizers.SGD(learning_rate=lr_rate)
  else:
   opt = keras.optimizers.Adamax(learning_rate=lr_rate)
  model.add(InputLayer(input_shape=(7,1)))
  model.add(LSTM(neuron_layer, return_sequences=True))
  model.add(Dense(10))
  model.add(LSTM(neuron_layer))
  model.add(Dense(1))
  model.compile(loss = 'mean_squared_error', optimizer=opt)
  return model

# %% [markdown]
# ### Hyperparameter Tuning
# ![Grid Search & Random Search](https://miro.medium.com/max/1200/1*ZTlQm_WRcrNqL-nLnx6GJA.png)

# %%
# Function to create the best model for hyperparameters method
def bestModel(least_loss, learning_rate_list, optimizer_list, neuron_list):
  for each_neuron in neuron_list:
    for each_optimizer in optimizer_list:
      for each_learning_rate in learning_rate_list:
        our_model = lstm_model(each_learning_rate, each_neuron, each_optimizer)
        our_model.fit(new_X_train, new_Y_train, 
                validation_data= 
                (new_X_val, new_Y_val)
                , epochs=100,batch_size=10,verbose=1,
                callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)])
        loss = our_model.evaluate(X_test, Y_test)
        if loss < least_loss:
          least_loss = loss
          best_learning_rate = each_learning_rate
          best_optimizer = each_optimizer
          best_neuron = each_neuron
    return least_loss, best_learning_rate, best_optimizer, best_neuron

# %% [markdown]
# #### Grid Search

# %%
neuron_list = [10,15,30,40]
optimizer_list = ['adam', 'adamax']
learning_rate_list = [3e-3, 3e-4,3e-5, 3e-6]
least_loss_grid_search = 1

best_grid_search_model = bestModel(least_loss_grid_search, learning_rate_list, optimizer_list, neuron_list)
print(best_grid_search_model)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0629 - val_loss: 0.0056
# Epoch 2/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0182 - val_loss: 0.0043
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0129 - val_loss: 0.0045
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0035
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0105 - val_loss: 0.0029
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0028
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0026
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0090 - val_loss: 0.0026
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0080 - val_loss: 0.0028
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0025
# Epoch 11/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0029
# Epoch 12/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 0.0032
# Epoch 13/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 14/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 15/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 16/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0018
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.4510 - val_loss: 0.2251
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2894 - val_loss: 0.1117
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1419 - val_loss: 0.0247
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0459 - val_loss: 0.0041
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0249 - val_loss: 0.0092
# Epoch 6/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0069
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0226 - val_loss: 0.0065
# 1/1 [==============================] - 0s 977us/step - loss: 0.0208
# Epoch 1/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.4248 - val_loss: 0.2700
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4085 - val_loss: 0.2578
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3925 - val_loss: 0.2460
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3770 - val_loss: 0.2344
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3616 - val_loss: 0.2228
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3462 - val_loss: 0.2114
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3309 - val_loss: 0.2001
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3157 - val_loss: 0.1886
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3005 - val_loss: 0.1772
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2850 - val_loss: 0.1661
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2697 - val_loss: 0.1547
# Epoch 12/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2543 - val_loss: 0.1432
# Epoch 13/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2387 - val_loss: 0.1320
# Epoch 14/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2232 - val_loss: 0.1209
# Epoch 15/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2078 - val_loss: 0.1098
# Epoch 16/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1925 - val_loss: 0.0991
# Epoch 17/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1774 - val_loss: 0.0887
# Epoch 18/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1627 - val_loss: 0.0786
# Epoch 19/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1483 - val_loss: 0.0688
# Epoch 20/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1344 - val_loss: 0.0596
# Epoch 21/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1211 - val_loss: 0.0509
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1084 - val_loss: 0.0429
# Epoch 23/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0966 - val_loss: 0.0356
# Epoch 24/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0856 - val_loss: 0.0290
# Epoch 25/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0755 - val_loss: 0.0233
# Epoch 26/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0664 - val_loss: 0.0183
# Epoch 27/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0583 - val_loss: 0.0143
# Epoch 28/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0512 - val_loss: 0.0108
# Epoch 29/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0452 - val_loss: 0.0081
# Epoch 30/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0400 - val_loss: 0.0061
# Epoch 31/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0357 - val_loss: 0.0047
# Epoch 32/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0323 - val_loss: 0.0038
# Epoch 33/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0296 - val_loss: 0.0033
# Epoch 34/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0274 - val_loss: 0.0032
# Epoch 35/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0258 - val_loss: 0.0032
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0245 - val_loss: 0.0034
# Epoch 37/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0037
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.3928 - val_loss: 0.2634
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3905 - val_loss: 0.2616
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3881 - val_loss: 0.2598
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3859 - val_loss: 0.2581
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3836 - val_loss: 0.2563
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3813 - val_loss: 0.2546
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3790 - val_loss: 0.2529
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3767 - val_loss: 0.2511
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3745 - val_loss: 0.2494
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3722 - val_loss: 0.2477
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3699 - val_loss: 0.2460
# Epoch 12/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3677 - val_loss: 0.2442
# Epoch 13/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3654 - val_loss: 0.2426
# Epoch 14/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3632 - val_loss: 0.2409
# Epoch 15/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3610 - val_loss: 0.2392
# Epoch 16/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3588 - val_loss: 0.2375
# Epoch 17/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3566 - val_loss: 0.2358
# Epoch 18/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3543 - val_loss: 0.2342
# Epoch 19/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3521 - val_loss: 0.2325
# Epoch 20/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3499 - val_loss: 0.2308
# Epoch 21/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3478 - val_loss: 0.2292
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3456 - val_loss: 0.2275
# Epoch 23/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3434 - val_loss: 0.2259
# Epoch 24/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3412 - val_loss: 0.2242
# Epoch 25/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3390 - val_loss: 0.2226
# Epoch 26/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3369 - val_loss: 0.2209
# Epoch 27/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3347 - val_loss: 0.2193
# Epoch 28/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3326 - val_loss: 0.2177
# Epoch 29/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3304 - val_loss: 0.2161
# Epoch 30/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3283 - val_loss: 0.2145
# Epoch 31/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3261 - val_loss: 0.2129
# Epoch 32/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3240 - val_loss: 0.2113
# Epoch 33/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3219 - val_loss: 0.2097
# Epoch 34/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3197 - val_loss: 0.2081
# Epoch 35/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3176 - val_loss: 0.2065
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3155 - val_loss: 0.2049
# Epoch 37/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3134 - val_loss: 0.2033
# Epoch 38/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3113 - val_loss: 0.2017
# Epoch 39/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3092 - val_loss: 0.2002
# Epoch 40/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3071 - val_loss: 0.1986
# Epoch 41/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3051 - val_loss: 0.1971
# Epoch 42/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3030 - val_loss: 0.1955
# Epoch 43/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3009 - val_loss: 0.1939
# Epoch 44/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2988 - val_loss: 0.1924
# Epoch 45/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2968 - val_loss: 0.1909
# Epoch 46/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2947 - val_loss: 0.1893
# Epoch 47/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2927 - val_loss: 0.1878
# Epoch 48/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2906 - val_loss: 0.1862
# Epoch 49/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2886 - val_loss: 0.1847
# Epoch 50/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2865 - val_loss: 0.1832
# Epoch 51/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2845 - val_loss: 0.1817
# Epoch 52/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2825 - val_loss: 0.1801
# Epoch 53/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2804 - val_loss: 0.1787
# Epoch 54/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2784 - val_loss: 0.1772
# Epoch 55/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2764 - val_loss: 0.1756
# Epoch 56/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2744 - val_loss: 0.1742
# Epoch 57/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2724 - val_loss: 0.1727
# Epoch 58/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2704 - val_loss: 0.1712
# Epoch 59/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2684 - val_loss: 0.1697
# Epoch 60/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2664 - val_loss: 0.1682
# Epoch 61/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2644 - val_loss: 0.1668
# Epoch 62/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2625 - val_loss: 0.1653
# Epoch 63/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2605 - val_loss: 0.1638
# Epoch 64/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2586 - val_loss: 0.1624
# Epoch 65/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2566 - val_loss: 0.1609
# Epoch 66/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2547 - val_loss: 0.1595
# Epoch 67/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2527 - val_loss: 0.1581
# Epoch 68/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2508 - val_loss: 0.1566
# Epoch 69/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2489 - val_loss: 0.1552
# Epoch 70/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2469 - val_loss: 0.1538
# Epoch 71/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2450 - val_loss: 0.1524
# Epoch 72/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2431 - val_loss: 0.1510
# Epoch 73/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2412 - val_loss: 0.1495
# Epoch 74/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2393 - val_loss: 0.1481
# Epoch 75/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2374 - val_loss: 0.1468
# Epoch 76/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2355 - val_loss: 0.1454
# Epoch 77/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2337 - val_loss: 0.1440
# Epoch 78/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2318 - val_loss: 0.1426
# Epoch 79/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2299 - val_loss: 0.1412
# Epoch 80/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2281 - val_loss: 0.1398
# Epoch 81/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2262 - val_loss: 0.1385
# Epoch 82/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2244 - val_loss: 0.1371
# Epoch 83/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2225 - val_loss: 0.1358
# Epoch 84/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2207 - val_loss: 0.1344
# Epoch 85/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2188 - val_loss: 0.1331
# Epoch 86/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2170 - val_loss: 0.1317
# Epoch 87/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2152 - val_loss: 0.1304
# Epoch 88/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2134 - val_loss: 0.1291
# Epoch 89/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2116 - val_loss: 0.1277
# Epoch 90/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2098 - val_loss: 0.1264
# Epoch 91/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2080 - val_loss: 0.1251
# Epoch 92/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2063 - val_loss: 0.1238
# Epoch 93/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2045 - val_loss: 0.1225
# Epoch 94/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2027 - val_loss: 0.1212
# Epoch 95/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2010 - val_loss: 0.1199
# Epoch 96/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1992 - val_loss: 0.1187
# Epoch 97/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1974 - val_loss: 0.1174
# Epoch 98/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1957 - val_loss: 0.1161
# Epoch 99/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1940 - val_loss: 0.1148
# Epoch 100/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1923 - val_loss: 0.1136
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2605
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0502 - val_loss: 0.0033
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0169 - val_loss: 0.0037
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0044
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0035
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0183
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.3109 - val_loss: 0.1439
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1830 - val_loss: 0.0665
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0954 - val_loss: 0.0218
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0455 - val_loss: 0.0047
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0256 - val_loss: 0.0037
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0212 - val_loss: 0.0054
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0204 - val_loss: 0.0058
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0202 - val_loss: 0.0060
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0170
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.4835 - val_loss: 0.3139
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4705 - val_loss: 0.3044
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4582 - val_loss: 0.2954
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4462 - val_loss: 0.2865
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4340 - val_loss: 0.2774
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4218 - val_loss: 0.2685
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4098 - val_loss: 0.2595
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3982 - val_loss: 0.2513
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3874 - val_loss: 0.2434
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3766 - val_loss: 0.2355
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3660 - val_loss: 0.2276
# Epoch 12/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3553 - val_loss: 0.2195
# Epoch 13/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3443 - val_loss: 0.2115
# Epoch 14/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3333 - val_loss: 0.2035
# Epoch 15/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3226 - val_loss: 0.1957
# Epoch 16/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3119 - val_loss: 0.1877
# Epoch 17/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3011 - val_loss: 0.1800
# Epoch 18/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2908 - val_loss: 0.1726
# Epoch 19/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2805 - val_loss: 0.1651
# Epoch 20/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2706 - val_loss: 0.1580
# Epoch 21/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2609 - val_loss: 0.1507
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2509 - val_loss: 0.1434
# Epoch 23/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2408 - val_loss: 0.1362
# Epoch 24/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2308 - val_loss: 0.1290
# Epoch 25/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2211 - val_loss: 0.1221
# Epoch 26/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2117 - val_loss: 0.1154
# Epoch 27/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2024 - val_loss: 0.1088
# Epoch 28/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1931 - val_loss: 0.1020
# Epoch 29/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1841 - val_loss: 0.0959
# Epoch 30/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1756 - val_loss: 0.0899
# Epoch 31/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1672 - val_loss: 0.0840
# Epoch 32/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1589 - val_loss: 0.0781
# Epoch 33/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1506 - val_loss: 0.0724
# Epoch 34/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1425 - val_loss: 0.0668
# Epoch 35/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1346 - val_loss: 0.0613
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1267 - val_loss: 0.0561
# Epoch 37/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1192 - val_loss: 0.0511
# Epoch 38/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1120 - val_loss: 0.0463
# Epoch 39/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1049 - val_loss: 0.0417
# Epoch 40/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0981 - val_loss: 0.0372
# Epoch 41/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0915 - val_loss: 0.0331
# Epoch 42/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0853 - val_loss: 0.0292
# Epoch 43/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0796 - val_loss: 0.0257
# Epoch 44/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0742 - val_loss: 0.0225
# Epoch 45/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0690 - val_loss: 0.0196
# Epoch 46/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0641 - val_loss: 0.0168
# Epoch 47/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0595 - val_loss: 0.0143
# Epoch 48/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0552 - val_loss: 0.0120
# Epoch 49/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0512 - val_loss: 0.0101
# Epoch 50/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0476 - val_loss: 0.0084
# Epoch 51/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0443 - val_loss: 0.0071
# Epoch 52/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0415 - val_loss: 0.0059
# Epoch 53/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0390 - val_loss: 0.0051
# Epoch 54/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0368 - val_loss: 0.0044
# Epoch 55/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0348 - val_loss: 0.0038
# Epoch 56/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0330 - val_loss: 0.0035
# Epoch 57/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0315 - val_loss: 0.0033
# Epoch 58/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0303 - val_loss: 0.0032
# Epoch 59/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0291 - val_loss: 0.0032
# Epoch 60/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0282 - val_loss: 0.0033
# Epoch 61/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0274 - val_loss: 0.0034
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0294
# Epoch 1/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.4579 - val_loss: 0.3046
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4565 - val_loss: 0.3036
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4551 - val_loss: 0.3025
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4538 - val_loss: 0.3015
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4524 - val_loss: 0.3004
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4510 - val_loss: 0.2993
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4495 - val_loss: 0.2982
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4481 - val_loss: 0.2973
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4469 - val_loss: 0.2963
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4456 - val_loss: 0.2953
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4443 - val_loss: 0.2943
# Epoch 12/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4430 - val_loss: 0.2933
# Epoch 13/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4417 - val_loss: 0.2923
# Epoch 14/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4403 - val_loss: 0.2912
# Epoch 15/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4390 - val_loss: 0.2902
# Epoch 16/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4376 - val_loss: 0.2892
# Epoch 17/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4363 - val_loss: 0.2882
# Epoch 18/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4350 - val_loss: 0.2872
# Epoch 19/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4337 - val_loss: 0.2862
# Epoch 20/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4324 - val_loss: 0.2853
# Epoch 21/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4312 - val_loss: 0.2843
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4299 - val_loss: 0.2833
# Epoch 23/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4285 - val_loss: 0.2823
# Epoch 24/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4272 - val_loss: 0.2813
# Epoch 25/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4259 - val_loss: 0.2803
# Epoch 26/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4246 - val_loss: 0.2793
# Epoch 27/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4233 - val_loss: 0.2783
# Epoch 28/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4220 - val_loss: 0.2773
# Epoch 29/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4207 - val_loss: 0.2764
# Epoch 30/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4194 - val_loss: 0.2754
# Epoch 31/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4182 - val_loss: 0.2745
# Epoch 32/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4169 - val_loss: 0.2735
# Epoch 33/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4156 - val_loss: 0.2725
# Epoch 34/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4143 - val_loss: 0.2715
# Epoch 35/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4129 - val_loss: 0.2704
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4116 - val_loss: 0.2694
# Epoch 37/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4103 - val_loss: 0.2685
# Epoch 38/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4089 - val_loss: 0.2675
# Epoch 39/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4076 - val_loss: 0.2665
# Epoch 40/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4063 - val_loss: 0.2655
# Epoch 41/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4050 - val_loss: 0.2645
# Epoch 42/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4037 - val_loss: 0.2635
# Epoch 43/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4025 - val_loss: 0.2626
# Epoch 44/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4012 - val_loss: 0.2617
# Epoch 45/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4000 - val_loss: 0.2607
# Epoch 46/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3987 - val_loss: 0.2597
# Epoch 47/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3974 - val_loss: 0.2587
# Epoch 48/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3961 - val_loss: 0.2577
# Epoch 49/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3948 - val_loss: 0.2568
# Epoch 50/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3935 - val_loss: 0.2558
# Epoch 51/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3922 - val_loss: 0.2549
# Epoch 52/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3911 - val_loss: 0.2540
# Epoch 53/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3899 - val_loss: 0.2532
# Epoch 54/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3887 - val_loss: 0.2522
# Epoch 55/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3875 - val_loss: 0.2513
# Epoch 56/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3862 - val_loss: 0.2504
# Epoch 57/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3850 - val_loss: 0.2495
# Epoch 58/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3839 - val_loss: 0.2486
# Epoch 59/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3827 - val_loss: 0.2477
# Epoch 60/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3815 - val_loss: 0.2468
# Epoch 61/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3803 - val_loss: 0.2459
# Epoch 62/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3790 - val_loss: 0.2450
# Epoch 63/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3777 - val_loss: 0.2440
# Epoch 64/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3765 - val_loss: 0.2431
# Epoch 65/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3752 - val_loss: 0.2421
# Epoch 66/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3740 - val_loss: 0.2412
# Epoch 67/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3728 - val_loss: 0.2403
# Epoch 68/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3715 - val_loss: 0.2394
# Epoch 69/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3703 - val_loss: 0.2384
# Epoch 70/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3691 - val_loss: 0.2375
# Epoch 71/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3679 - val_loss: 0.2366
# Epoch 72/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3666 - val_loss: 0.2357
# Epoch 73/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3654 - val_loss: 0.2348
# Epoch 74/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3642 - val_loss: 0.2339
# Epoch 75/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3629 - val_loss: 0.2330
# Epoch 76/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3617 - val_loss: 0.2320
# Epoch 77/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3605 - val_loss: 0.2311
# Epoch 78/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3592 - val_loss: 0.2302
# Epoch 79/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3580 - val_loss: 0.2293
# Epoch 80/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3568 - val_loss: 0.2284
# Epoch 81/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3556 - val_loss: 0.2275
# Epoch 82/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3544 - val_loss: 0.2266
# Epoch 83/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3532 - val_loss: 0.2258
# Epoch 84/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3521 - val_loss: 0.2249
# Epoch 85/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3509 - val_loss: 0.2240
# Epoch 86/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3497 - val_loss: 0.2231
# Epoch 87/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3484 - val_loss: 0.2221
# Epoch 88/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3472 - val_loss: 0.2212
# Epoch 89/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3460 - val_loss: 0.2204
# Epoch 90/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3448 - val_loss: 0.2195
# Epoch 91/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3436 - val_loss: 0.2186
# Epoch 92/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3425 - val_loss: 0.2178
# Epoch 93/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3413 - val_loss: 0.2169
# Epoch 94/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3402 - val_loss: 0.2160
# Epoch 95/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3390 - val_loss: 0.2152
# Epoch 96/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3379 - val_loss: 0.2143
# Epoch 97/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3367 - val_loss: 0.2134
# Epoch 98/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3355 - val_loss: 0.2125
# Epoch 99/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3343 - val_loss: 0.2116
# Epoch 100/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3330 - val_loss: 0.2107
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4290
# (0.0011817968916147947, 0.003, 'adam', 10)

# %% [markdown]
# #### Random Search

# %%
# Shuffling neuron layers
neuron_list = [15,30,10]
# Seed random number generator
seed(len(neuron_list))
# Prepare a sequence
neuron_sequence = neuron_list
print(neuron_sequence) # Before Shuffle
# Randomly shuffle the sequence hidden layers
shuffle(neuron_sequence) 
print(neuron_sequence) # After Shuffle
# Out:
# [15, 30, 10]
# [30, 15, 10]

# %%
# Shuffling optimizers

optimizer_list = ['adam', 'adamax']
# Seed random number generator
seed(len(neuron_sequence))
# Prepare a sequence
op_sequence = optimizer_list
print(op_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(op_sequence)
print(op_sequence) # After Shuffle
# Out:
# ['adam', 'adamax']
# ['adam', 'adamax']

# %%
# Shuffling learning rate

learning_rate_list = [3e-3,3e-4]
# Seed random number generator
seed(len(neuron_sequence))
# Prepare a sequence
lr_sequence = learning_rate_list
print(lr_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(lr_sequence)
print(lr_sequence) # After Shuffle
# Out:
# [0.003, 0.0003]
# [0.0003, 0.003]

# %%
# Assigning least_loss
least_loss_random_search = 1

# %%
best_random_grid_model = bestModel(least_loss_random_search, lr_sequence, op_sequence, neuron_sequence)
print(best_random_grid_model)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.3015 - val_loss: 0.0900
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0624 - val_loss: 0.0081
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0186 - val_loss: 0.0038
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0166 - val_loss: 0.0040
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0160 - val_loss: 0.0045
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0038
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0152 - val_loss: 0.0038
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0038
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0036
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0142 - val_loss: 0.0036
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0036
# Epoch 12/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0137 - val_loss: 0.0037
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0112
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0870 - val_loss: 0.0246
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0199 - val_loss: 0.0035
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0037
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0037
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0128 - val_loss: 0.0033
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0032
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0115 - val_loss: 0.0030
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0028
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.0032
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0085 - val_loss: 0.0071
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0105 - val_loss: 0.0032
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0050
# Epoch 1/100
# 33/33 [==============================] - 1s 25ms/step - loss: 0.3541 - val_loss: 0.1617
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.1834 - val_loss: 0.0434
# Epoch 3/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0471 - val_loss: 0.0041
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0205 - val_loss: 0.0063
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0200 - val_loss: 0.0057
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0194 - val_loss: 0.0052
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0156
# Epoch 1/100
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0686 - val_loss: 0.0039
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0178 - val_loss: 0.0042
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0053
# Epoch 4/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0037
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0035
# Epoch 6/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0041
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0035
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.0035
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0086
# (0.004981833044439554, 0.003, 'adam', 30)

# %% [markdown]
# #### Deciding on best hyperparameter results

# %%
# We want the smallest loss
# Therefore if random_search least loss is greater than grid search, make grid search best model the best model.
# 0 = least loss, 1 = learning rate, 2 = optimizer, 3 = neurons
if best_grid_search_model[0] > best_random_grid_model[0]:
  best_learning_rate = best_random_grid_model[1]
  best_optimizer = best_random_grid_model[2]
  best_neuron = best_random_grid_model[3]
else:
  best_learning_rate = best_grid_search_model[1]
  best_optimizer = best_grid_search_model[2]
  best_neuron = best_grid_search_model[3]
print(best_learning_rate)
print(best_optimizer)
print(best_neuron)
# Out:
# 0.003
# adam
# 10

# %% [markdown]
# # Best Model Prediction

# %%
best_param_model = lstm_model(best_learning_rate, best_neuron, best_optimizer)
best_param_model.fit(X_train, Y_train, epochs=150,batch_size=10,verbose=1)
loss = best_param_model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1675
# Epoch 2/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0341
# Epoch 3/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0245
# Epoch 4/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0189
# Epoch 5/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0162
# Epoch 6/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0131
# Epoch 7/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0137
# Epoch 8/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0139
# Epoch 9/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0127
# Epoch 10/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0116
# Epoch 11/150
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0112
# Epoch 12/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0112
# Epoch 13/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0114
# Epoch 14/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0109
# Epoch 15/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0109
# Epoch 16/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0096
# Epoch 17/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0100
# Epoch 18/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0096
# Epoch 19/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0088
# Epoch 20/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 21/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0088
# Epoch 22/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 23/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 24/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 25/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063
# Epoch 26/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061
# Epoch 27/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058
# Epoch 28/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 29/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053
# Epoch 30/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0085
# Epoch 31/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 32/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050
# Epoch 33/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 34/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 35/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 36/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 37/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 38/150
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 39/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044
# Epoch 40/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 41/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 42/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 43/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 44/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 45/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 46/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 47/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 48/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 49/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 50/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 51/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 52/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 53/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 54/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 55/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 56/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 57/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 58/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 59/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 60/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 61/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 62/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 63/150
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 64/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 65/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 66/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 67/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 68/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 69/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 70/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 71/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 72/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 73/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 74/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 75/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 76/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 77/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 78/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 79/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 80/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 81/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 82/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 83/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 84/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 85/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 86/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 87/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 88/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 89/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 90/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 91/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 92/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 93/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 94/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 95/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 96/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 97/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 98/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 99/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 100/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 101/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 102/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 103/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 104/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 105/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 106/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 107/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 108/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 109/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 110/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 111/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 112/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 113/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 114/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 115/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 116/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 117/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 118/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 119/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 120/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 121/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 122/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 123/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 124/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 125/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 126/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 127/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 128/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 129/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 130/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 131/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 132/150
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0021
# Epoch 133/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 134/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 135/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 136/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 137/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 138/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 139/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 140/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 141/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 142/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 143/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 144/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 145/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 146/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 147/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 148/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 149/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 150/150
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021
# 1/1 [==============================] - 0s 1ms/step - loss: 9.9343e-04

# %% [markdown]
# # Using best model to predict on X_train & X_test

# %%
# Prediction and check performance metric
train_predict = best_param_model.predict(X_train)
test_predict = best_param_model.predict(X_test)
print(train_predict.shape)
print(test_predict.shape)
# Out:
# (163, 1)
# (14, 1)

# %% [markdown]
# # Performance Metric

# %%
def get_performance_train (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_train, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_train, model_pred).round(4))
  print('R2_Score:',r2_score(Y_train, model_pred).round(4))

# %%
def get_performance_test (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_test, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_test, model_pred).round(4))  
  print('R2_Score:',r2_score(Y_test, model_pred).round(4))

# %%
print('Train:')
get_performance_train(train_predict)
print('\nTest:')
get_performance_test(test_predict)
# Out:
# Train:
# Mean Absolute Error: 0.0295
# Mean Squared Error: 0.0019
# R2_Score: 0.9582
#
# Test:
# Mean Absolute Error: 0.0249
# Mean Squared Error: 0.001
# R2_Score: 0.8475

# %% [markdown]
# # Plotting Train Prediction, Validation & Test Prediction Versus Actual Data

# %%
# Transform back to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict =scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Train Predicted

# %%
look_back = 7

trainPredictPlot = np.empty_like(new_dataset) # shape
trainPredictPlot[:,:]= np.nan # values at 0
trainPredictPlot[look_back:len(train_predict)+look_back] = train_predict # Populates: 7 -> 162 + 7 = 169

trainPredictPlot = [item[0] for item in trainPredictPlot]
plt.plot(trainPredictPlot, label="train_predict_price")

train_panda = pd.DataFrame(train_data)
plt.plot(scaler.inverse_transform(train_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# ## Using last 7 days of training data to predict validation data.

# %%
temp_input = train_data[-7:]
temp_input
# Out:
# array([[0.59470124],
#        [0.62965051],
#        [0.62965051],
#        [0.62965051],
#        [0.61443067],
#        [0.60315671],
#        [0.52931229]])

# %%
# Demonstrate prediction for the next 4 as an example(but 21) days:

# Step 1. 7 days of feature = temp_input taken from the last 7 days of the training set
# Step 2  i is the day you are on and we want to predict 4 days: 0,1,2,3 (4 days)
# Step 3. Predict the 8th day on each of the 7 days,
# Step 4. Add this new predicted day to the list
# Step 5. Because we are now taking in the last 7 days + the new predicted value, the list is now size 8  
# Step 6. In order to take in 7 days at a time, we shift 1 to the right.
# Step 7. We reassign the X_train to the new 7 days
# Step 8. We predict the 8th day of the 7 days and continue the process
# Step 9. We then add the 8th day to the output list
# Step 10. We keep track of the 4 days by incrementing by i at the end-> i = i+1
# Step 11. Once we have predicted the 4 days, we return the list of 4 day values.

custom_day = len(valset_data)
lst_output=[]
n_steps=7
i=0
X_input = temp_input
# print(X_input)
while(i<custom_day):
  if(len(temp_input)>7):
    # print(temp_input)  
    X_input=array(temp_input[1:])
    # print("{} day input {}".format(i,X_input))
    # Correct input shape (1,7,3)
    X_input=X_input.reshape((1,n_steps,1))
    # Prediction of X_input
    # print(X_input)
    Y_hat = best_param_model.predict(X_input)
    # print(Y_hat)
    temp_input = np.append(temp_input, Y_hat)
    temp_input=temp_input[1:]
    lst_output.append(Y_hat[0][0])
    i=i+1
  else:
    X_input=X_input.reshape((1,n_steps,1))
    Y_hat = best_param_model.predict(X_input, verbose=0)
    # print(Y_hat)
    temp_input = np.append(temp_input, Y_hat)
    lst_output.append(Y_hat[0][0])
    i=i+1
print(lst_output)
# Out:
# [0.5088098, 0.4968769, 0.48892125, 0.48463166, 0.4827977, 0.48245764, 0.48306087, 0.4843069, 0.48594064, 0.4877786, 0.489694, 0.49160042, 0.4934412, 0.4951817, 0.49680316, 0.49829784, 0.49966556, 0.5009106, 0.50204015, 0.50306284, 0.50398785]

# %% [markdown]
# ## Plotting evaluation: Training Prediction of Validation Data

# %%
# Custom day plotted
day_new = custom_day-1

# Transform back to original value before normalised
custom_day_prediction = np.array(lst_output)
# print("Predicted validation:")
# print(custom_day_prediction)
plt.plot(custom_day_prediction, label="Predicted Validation Data")

# Transform back to original value before normalised
val_data = [item[0] for item in valset_data] 
custom_day_validation = val_data[:custom_day]
# print("Actual validation:")
# print(custom_day_validation)
plt.plot(custom_day_validation, label="Actual Validation Data")

rcParams['figure.figsize'] = 15,6
plt.title('Training Prediction of Validation Data', size = 20)
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Plot

# %%
look_back = 7

testPredictPlot = np.empty_like(new_dataset)
testPredictPlot[:,:]= np.nan
testPredictPlot[look_back:len(test_predict)+look_back] = test_predict
# 14 + (7*2) + 1 : 163 + 14 = test_predict
# 22:177 = test predict

testPredictPlot = [item[0] for item in testPredictPlot]
plt.plot(testPredictPlot, label="test_predict")

test_panda = pd.DataFrame(test_data)
plt.plot(scaler.inverse_transform(test_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train, test and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()
