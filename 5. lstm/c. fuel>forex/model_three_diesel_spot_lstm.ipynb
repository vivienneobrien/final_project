# %% [markdown]
# # Model #3 Multivariate LSTM (Diesel -> Spot Price)
# * Import fuel_prices_com.csv & GBP_USD.csv
# * Using Fuel Prices and Forex Spot Price as input into an LSTM model to predict Forex Spot Price of the currency pair in question.

# %% [markdown]
# # Imports

# %%
# Imports
# !pip install git+https://github.com/tensorflow/docs
import tensorflow as tf
print(tf.__version__)

# Libraries
import pathlib
import numpy as np
import pandas as pd
from numpy import array

# Plotting
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
plt.style.use('seaborn')
from matplotlib import rcParams

# Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer, Dense, LSTM, Dropout
from numpy.random import seed
from random import shuffle

# Metric
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt
# Out:
# Collecting git+https://github.com/tensorflow/docs
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-srq_eo3k
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-srq_eo3k
# Requirement already satisfied (use --upgrade to upgrade): tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968- from git+https://github.com/tensorflow/docs in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: astor in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (0.8.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorflow-docs===0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968-) (49.6.0)
# Building wheels for collected packages: tensorflow-docs
#   Building wheel for tensorflow-docs (setup.py) ... done
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0ff623b83a13034bdb4f84fc1299e7a2e23267968_-cp36-none-any.whl size=146353 sha256=cd2d4c095bc42777a4bf8f76a3318b80397ba9467e77d0eb2a2650f8ff1959f7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5dxqpb6x/wheels/eb/1b/35/fce87697be00d2fc63e0b4b395b0d9c7e391a10e98d9a0d97f
# Successfully built tensorflow-docs
# 2.3.0

# %%
seed(1)
tf.random.set_seed(2)

# %% [markdown]
# # Data Collection

# %%
# Import forex
forex_dataset_data= pd.read_csv('GBP_USD.csv', na_values = "?", comment='\t', skipinitialspace=True)
forex_dataset = forex_dataset_data.copy()
forex_dataset = forex_dataset.fillna(method='ffill')
forex_dataset = pd.DataFrame(forex_dataset,columns=['Price','Date'])

# %%
# Import price
fuel_dataset = pd.read_csv('fuel_prices_com.csv', encoding= 'unicode_escape')
fuel_dataset = fuel_dataset.loc[fuel_dataset.Country=='USA', ['Date','Diesel']]

# %% [markdown]
# # Data Preprocessing / Data Cleaning & Collating
# *   We first isolate the date column both fuel_dataset and forex_dataset so that they are formatted in the same way.
# *   Challenge: Fuel Price dataset is a weekly timeseries dataset whereas Forex Price is a daily timeseries dataset.

# %%
fuel_dataset['Date'] = fuel_dataset['Date'].apply(lambda x: pd.to_datetime(str(x)))
fuel_dataset['Date'].head()
# Out:
# 772   2020-06-01
# 773   2020-01-13
# 774   2020-01-20
# 775   2020-01-27
# 776   2020-03-02
# Name: Date, dtype: datetime64[ns]

# %%
# We find out the format for where the day, month and year lie.
fuel_dataset["Date"] = pd.to_datetime(fuel_dataset["Date"], format="%d-%m-%Y")
forex_dataset["Date"] = pd.to_datetime(forex_dataset["Date"], format="%b %d, %Y")
# We transform these values to the same format.
fuel_dataset["Date"] = fuel_dataset["Date"].dt.strftime("%d-%m-%Y")
forex_dataset["Date"] = forex_dataset["Date"].dt.strftime("%d-%m-%Y")
# We then convert them back to a dataframe.
fuel_dataset["Date"] = pd.to_datetime(fuel_dataset["Date"], format="%d-%m-%Y")
forex_dataset["Date"] = pd.to_datetime(forex_dataset["Date"], format="%d-%m-%Y")

# %%
# We set the index for both datasets to be date.
forex_dataset.set_index("Date", inplace=True)
fuel_dataset.set_index("Date", inplace=True)
forex_dataset["Date"] = forex_dataset.index
fuel_dataset["date"] = fuel_dataset.index

# %%
# We then group these dates in a weekly period column
fuel_dataset["week"] = fuel_dataset.index.to_period('W')
forex_dataset["week"] = forex_dataset.index.to_period('W')

# %%
# We then join our datasets on the week column
data_ff = pd.merge(
    forex_dataset,
    fuel_dataset,
    left_on="week",
    right_on="week",
    how="left"
)

# %%
data_ff[data_ff.Diesel.isnull() | data_ff.Price.isnull()]
# Out:
#       Price       Date                   week  Diesel date
# 15   1.2542 2020-06-12  2020-06-08/2020-06-14     NaN  NaT
# 16   1.2602 2020-06-11  2020-06-08/2020-06-14     NaN  NaT
# 17   1.2747 2020-06-10  2020-06-08/2020-06-14     NaN  NaT
# 18   1.2731 2020-06-09  2020-06-08/2020-06-14     NaN  NaT
# 19   1.2723 2020-06-08  2020-06-08/2020-06-14     NaN  NaT
# 45   1.2106 2020-05-15  2020-05-11/2020-05-17     NaN  NaT
# 46   1.2228 2020-05-14  2020-05-11/2020-05-17     NaN  NaT
# 47   1.2230 2020-05-13  2020-05-11/2020-05-17     NaN  NaT
# 48   1.2261 2020-05-12  2020-05-11/2020-05-17     NaN  NaT
# 49   1.2336 2020-05-11  2020-05-11/2020-05-17     NaN  NaT
# 50   1.2409 2020-05-08  2020-05-04/2020-05-10     NaN  NaT
# 51   1.2363 2020-05-07  2020-05-04/2020-05-10     NaN  NaT
# 52   1.2343 2020-05-06  2020-05-04/2020-05-10     NaN  NaT
# 53   1.2436 2020-05-05  2020-05-04/2020-05-10     NaN  NaT
# 54   1.2444 2020-05-04  2020-05-04/2020-05-10     NaN  NaT
# 70   1.2455 2020-04-10  2020-04-06/2020-04-12     NaN  NaT
# 71   1.2457 2020-04-09  2020-04-06/2020-04-12     NaN  NaT
# 72   1.2387 2020-04-08  2020-04-06/2020-04-12     NaN  NaT
# 73   1.2339 2020-04-07  2020-04-06/2020-04-12     NaN  NaT
# 74   1.2230 2020-04-06  2020-04-06/2020-04-12     NaN  NaT
# 95   1.2277 2020-03-13  2020-03-09/2020-03-15     NaN  NaT
# 96   1.2573 2020-03-12  2020-03-09/2020-03-15     NaN  NaT
# 97   1.2822 2020-03-11  2020-03-09/2020-03-15     NaN  NaT
# 98   1.2908 2020-03-10  2020-03-09/2020-03-15     NaN  NaT
# 99   1.3133 2020-03-09  2020-03-09/2020-03-15     NaN  NaT
# 115  1.3047 2020-02-14  2020-02-10/2020-02-16     NaN  NaT
# 116  1.3047 2020-02-13  2020-02-10/2020-02-16     NaN  NaT
# 117  1.2961 2020-02-12  2020-02-10/2020-02-16     NaN  NaT
# 118  1.2953 2020-02-11  2020-02-10/2020-02-16     NaN  NaT
# 119  1.2915 2020-02-10  2020-02-10/2020-02-16     NaN  NaT
# 145  1.3088 2020-01-03  2019-12-30/2020-01-05     NaN  NaT
# 146  1.3146 2020-01-02  2019-12-30/2020-01-05     NaN  NaT
# 147  1.3255 2020-01-01  2019-12-30/2020-01-05     NaN  NaT
# 148  1.3261 2019-12-31  2019-12-30/2020-01-05     NaN  NaT
# 149  1.3115 2019-12-30  2019-12-30/2020-01-05     NaN  NaT
# 150  1.3077 2019-12-27  2019-12-23/2019-12-29     NaN  NaT
# 151  1.2993 2019-12-26  2019-12-23/2019-12-29     NaN  NaT
# 152  1.2961 2019-12-25  2019-12-23/2019-12-29     NaN  NaT
# 153  1.2946 2019-12-24  2019-12-23/2019-12-29     NaN  NaT
# 154  1.2935 2019-12-23  2019-12-23/2019-12-29     NaN  NaT
# 155  1.3004 2019-12-20  2019-12-16/2019-12-22     NaN  NaT
# 156  1.3009 2019-12-19  2019-12-16/2019-12-22     NaN  NaT
# 157  1.3078 2019-12-18  2019-12-16/2019-12-22     NaN  NaT
# 158  1.3130 2019-12-17  2019-12-16/2019-12-22     NaN  NaT
# 159  1.3331 2019-12-16  2019-12-16/2019-12-22     NaN  NaT
# 160  1.3326 2019-12-13  2019-12-09/2019-12-15     NaN  NaT
# 161  1.3164 2019-12-12  2019-12-09/2019-12-15     NaN  NaT
# 162  1.3195 2019-12-11  2019-12-09/2019-12-15     NaN  NaT
# 163  1.3156 2019-12-10  2019-12-09/2019-12-15     NaN  NaT
# 164  1.3145 2019-12-09  2019-12-09/2019-12-15     NaN  NaT
# 165  1.3137 2019-12-06  2019-12-02/2019-12-08     NaN  NaT
# 166  1.3157 2019-12-05  2019-12-02/2019-12-08     NaN  NaT
# 167  1.3104 2019-12-04  2019-12-02/2019-12-08     NaN  NaT
# 168  1.2994 2019-12-03  2019-12-02/2019-12-08     NaN  NaT
# 169  1.2937 2019-12-02  2019-12-02/2019-12-08     NaN  NaT

# %%
# We isolate the features that we want in our dataset
data_ff = pd.DataFrame(data_ff, columns = ['Date', 'Price', 'Diesel']) 
data_ff['Diesel'].fillna((data_ff['Diesel'].mean()), inplace=True) # Notice how our dataset starts from the end rather than the top
dataset = data_ff.iloc[::-1,:] # Reverse order of dataset
dataset.reset_index(drop=True, inplace=True) #Reset index

# %%
dataset = pd.DataFrame(dataset, columns = ['Date', 'Price', 'Diesel']) 
dataset
# Out:
#           Date   Price    Diesel
# 0   2019-12-02  1.2937  0.699826
# 1   2019-12-03  1.2994  0.699826
# 2   2019-12-04  1.3104  0.699826
# 3   2019-12-05  1.3157  0.699826
# 4   2019-12-06  1.3137  0.699826
# ..         ...     ...       ...
# 165 2020-06-29  1.2299  0.644000
# 166 2020-06-30  1.2401  0.644000
# 167 2020-07-01  1.2474  0.644000
# 168 2020-07-02  1.2467  0.644000
# 169 2020-07-03  1.2482  0.644000
#
# [170 rows x 3 columns]

# %% [markdown]
# # Plotting Features before Normalisation

# %% [markdown]
# ### Organising date for plotting

# %%
# Isolate date for plotting
date = dataset['Date']
# Isolate dates in question
dateFormatting = pd.DataFrame({'new_date': pd.date_range('2019-12-31', '2020-07-31', periods=len(date))})
# Convert date to list so that we can use the dates to plot on graph
my_xticks = dateFormatting['new_date'].tolist()

# %% [markdown]
# ### Plotting Forex Spot Price

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
price = np.array(dataset['Price'])
plt.plot_date(dates,price, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series Price of Forex Spot Price', size = 20)
plt.xlabel('Date')
plt.ylabel('Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# ### Plotting Diesel Prices

# %%
rcParams['figure.figsize'] = 15,6
dates = np.array(dateFormatting['new_date'])
fuel = np.array(dataset['Diesel'])
plt.plot_date(dates,fuel, linestyle ='solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter('%b,%d,%Y')
plt.title('Time Series of Fuel Prices', size = 20)
plt.xlabel('Date')
plt.ylabel('Fuel Price')
plt.gca().xaxis.set_major_formatter(date_format)

# %% [markdown]
# # Plotting Features after Normalisation

# %%
price_frame = pd.DataFrame(np.concatenate([price]), columns= ["Price"])
fuel_frame = pd.DataFrame(np.concatenate([fuel]), columns= ["Fuel Price"])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
normalisation_price = scaler.fit_transform(price_frame).reshape(-1,1)
normalisation_fuel_price = scaler.fit_transform(fuel_frame).reshape(-1,1)

# %%
rcParams['figure.figsize'] = 15,6
plt.plot(normalisation_price, label="Spot Price")
plt.plot(normalisation_fuel_price, label="Fuel Price")
dates = np.array(dateFormatting['new_date'])
plt.title('Time Series of Fuel Prices & Forex Price', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend() 
plt.show()

# %% [markdown]
# # Splitting Data into Train, Validation & Test

# %%
new_dataset = np.hstack((normalisation_fuel_price, normalisation_price))

# %%
# Test, Validation, Train 
training_size = int(len(new_dataset)*0.80)
test_size = (len(new_dataset)-training_size)//2 # // Rounds down
train_data, valset_data, test_data = new_dataset[0:training_size], new_dataset[training_size:(training_size + test_size)],new_dataset[(training_size + test_size):]
print(train_data.shape)
print(valset_data.shape)
print(test_data.shape)
# Out:
# (136, 2)
# (17, 2)
# (17, 2)

# %%
# Start – Train
rcParams['figure.figsize'] = 15,6
plt.plot(train_data, label="Actual Train Dataset")
plt.title('Normalised Train Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# Middle – Validation
rcParams['figure.figsize'] = 15,6
plt.plot(valset_data, label="Actual validation dataset")
plt.title('Normalised Validation Dataset', size = 20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
# End - Test
rcParams['figure.figsize'] = 15,6
plt.plot(test_data, label="Actual test dataset")
plt.title('Normalised Test Data', size =20)
plt.ylabel('Normalised Data')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# # X_train, Y_train, X_test, Y_test

# %%
# Convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
  dataX, dataY = [],[]
  # range: is the days in dataset - the days we need to consider - the 8th day
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step)]  # from i -> 6th day
    dataX.append(a) 
    y = dataset[i + time_step][1] # 7th day
    dataY.append(y)
  return np.array(dataX), np.array(dataY)

# %%
# Weekly_timestep means taking in 7 days of features at a time 
weekly_timestep = 7
X_train, Y_train = create_dataset(train_data, weekly_timestep)
X_val, Y_val = create_dataset(valset_data, weekly_timestep)
X_test, Y_test = create_dataset(test_data, weekly_timestep)

# %% [markdown]
# ## Data Augmentation

# %%
reversed_x_train = X_train[::-1]
reversed_y_train = Y_train[::-1]
reversed_x_val = X_val[::-1]
reversed_y_val = Y_val[::-1]

new_X_train = np.concatenate((X_train, reversed_x_train))
new_Y_train = np.concatenate((Y_train, reversed_y_train))
new_X_val = np.concatenate((X_val, reversed_x_val))
new_Y_val = np.concatenate((Y_val, reversed_y_val))
print(len(new_X_train))
print(len(new_Y_train))
print(len(new_X_val)) 
print(len(new_Y_val))
# Out:
# 256
# 256
# 18
# 18

# %% [markdown]
# # Stacked LSTM Model

# %%
def lstm_model(lr_rate, neuron_layer, optimizer_one):
  model = Sequential()
  opt = None
  if optimizer_one == 'adam':
   opt = keras.optimizers.Adam(learning_rate=lr_rate)
  elif optimizer_one == 'sgd':
   opt = keras.optimizers.SGD(learning_rate=lr_rate)
  else:
   opt = keras.optimizers.Adamax(learning_rate=lr_rate)
  model.add(InputLayer(input_shape=(7,2)))
  model.add(LSTM(neuron_layer, return_sequences=True))
  model.add(Dense(10))
  model.add(LSTM(neuron_layer))
  model.add(Dense(1))
  model.compile(loss = 'mean_squared_error', optimizer=opt)
  return model

# %% [markdown]
# ## Hyperparameter Tuning
# ![Grid Search & Random Search](https://miro.medium.com/max/1200/1*ZTlQm_WRcrNqL-nLnx6GJA.png)

# %%
# Function to create the best model for hyperparameters method
def bestModel(least_loss, learning_rate_list, optimizer_list, neuron_list):
  for each_neuron in neuron_list:
    for each_optimizer in optimizer_list:
      for each_learning_rate in learning_rate_list:
        our_model = lstm_model(each_learning_rate, each_neuron, each_optimizer)
        our_model.fit(new_X_train, new_Y_train, 
                validation_data= 
                (new_X_val, new_Y_val)
                , epochs=100,batch_size=10,verbose=1,
                callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)])
        loss = our_model.evaluate(X_test, Y_test)
        if loss < least_loss:
          least_loss = loss
          best_learning_rate = each_learning_rate
          best_optimizer = each_optimizer
          best_neuron = each_neuron
    return least_loss, best_learning_rate, best_optimizer, best_neuron

# %% [markdown]
# ### Grid Search

# %%
neuron_list = [15,30,10]
optimizer_list = ['adam', 'adamax']
learning_rate_list = [3e-3,3e-4]
least_loss_grid_search = 1

best_grid_search_model = bestModel(least_loss_grid_search, learning_rate_list, optimizer_list, neuron_list)
print(best_grid_search_model)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.1035 - val_loss: 0.0034
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0206 - val_loss: 4.6170e-04
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0172 - val_loss: 0.0015
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0145 - val_loss: 0.0048
# Epoch 5/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0150 - val_loss: 0.0014
# 1/1 [==============================] - 0s 922us/step - loss: 0.0012
# Epoch 1/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1866 - val_loss: 0.0810
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0653 - val_loss: 0.0068
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0248 - val_loss: 0.0011
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0243 - val_loss: 6.4784e-04
# Epoch 5/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0235 - val_loss: 5.9738e-04
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0229 - val_loss: 5.3338e-04
# Epoch 7/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0225 - val_loss: 5.3458e-04
# Epoch 8/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0217 - val_loss: 5.2887e-04
# Epoch 9/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0211 - val_loss: 4.6733e-04
# Epoch 10/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0206 - val_loss: 4.6732e-04
# Epoch 11/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 5.4521e-04
# Epoch 12/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0192 - val_loss: 4.2942e-04
# Epoch 13/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0186 - val_loss: 6.3204e-04
# Epoch 14/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 6.1109e-04
# Epoch 15/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0175 - val_loss: 4.6726e-04
# 1/1 [==============================] - 0s 986us/step - loss: 0.0026
# Epoch 1/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.1058 - val_loss: 7.8250e-04
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0261 - val_loss: 0.0015
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0231 - val_loss: 5.9144e-04
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0205 - val_loss: 4.2254e-04
# Epoch 5/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0180 - val_loss: 0.0027
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0169 - val_loss: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0164 - val_loss: 0.0023
# 1/1 [==============================] - 0s 956us/step - loss: 0.0014
# Epoch 1/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.2876 - val_loss: 0.1912
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1819 - val_loss: 0.1047
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0980 - val_loss: 0.0409
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0452 - val_loss: 0.0085
# Epoch 5/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0251 - val_loss: 9.6394e-04
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0211 - val_loss: 4.7821e-04
# Epoch 7/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0208 - val_loss: 4.6022e-04
# Epoch 8/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0205 - val_loss: 4.6822e-04
# Epoch 9/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0203 - val_loss: 5.1878e-04
# Epoch 10/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 4.4339e-04
# Epoch 11/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0196 - val_loss: 4.9117e-04
# Epoch 12/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0194 - val_loss: 5.2937e-04
# Epoch 13/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0191 - val_loss: 5.0896e-04
# 1/1 [==============================] - 0s 993us/step - loss: 0.0037
# (0.0012231387663632631, 0.003, 'adam', 15)

# %% [markdown]
# ### Random Search

# %%
# Shuffling neuron layers

neuron_list = [15,30,10]
# Seed random number generator
seed(len(neuron_list))
# Prepare a sequence
neuron_sequence = neuron_list
print(neuron_sequence) # Before Shuffle
# Randomly shuffle the sequence hidden layers
shuffle(neuron_sequence) 
print(neuron_sequence) # After Shuffle
# Out:
# [15, 30, 10]
# [10, 15, 30]

# %%
# Shuffling optimizers

optimizer_list = ['adam', 'adamax']
# Seed random number generator
seed(len(neuron_sequence))
# Prepare a sequence
op_sequence = optimizer_list
print(op_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(op_sequence)
print(op_sequence) # After Shuffle
# Out:
# ['adam', 'adamax']
# ['adamax', 'adam']

# %%
# Shuffling learning rate

learning_rate_list = [3e-3,3e-4]
# Seed random number generator
seed(len(neuron_sequence))
# Prepare a sequence
lr_sequence = learning_rate_list
print(lr_sequence) # Before Shuffle
# Randomly shuffle the sequence
shuffle(lr_sequence)
print(lr_sequence) # After Shuffle
# Out:
# [0.003, 0.0003]
# [0.0003, 0.003]

# %%
# Assigning least_loss
least_loss_random_search = 1

# %%
best_random_grid_model = bestModel(least_loss_random_search, lr_sequence, op_sequence, neuron_sequence)
print(best_random_grid_model)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.3021 - val_loss: 0.2104
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2243 - val_loss: 0.1430
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1544 - val_loss: 0.0837
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0971 - val_loss: 0.0382
# Epoch 5/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0576 - val_loss: 0.0122
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0366 - val_loss: 0.0027
# Epoch 7/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0297 - val_loss: 7.5627e-04
# Epoch 8/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0278 - val_loss: 7.5788e-04
# Epoch 9/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0274 - val_loss: 7.7555e-04
# Epoch 10/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0271 - val_loss: 8.9282e-04
# 1/1 [==============================] - 0s 942us/step - loss: 0.0023
# Epoch 1/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1009 - val_loss: 0.0019
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0228 - val_loss: 0.0011
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 4.4304e-04
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0179 - val_loss: 4.8563e-04
# Epoch 5/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0158 - val_loss: 0.0026
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0149 - val_loss: 0.0011
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0055
# Epoch 1/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.4963 - val_loss: 0.3523
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.3571 - val_loss: 0.2367
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2380 - val_loss: 0.1326
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1297 - val_loss: 0.0438
# Epoch 5/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0524 - val_loss: 0.0026
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0276 - val_loss: 9.3591e-04
# Epoch 7/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0267 - val_loss: 6.6050e-04
# Epoch 8/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0259 - val_loss: 5.3829e-04
# Epoch 9/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0253 - val_loss: 5.0161e-04
# Epoch 10/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0247 - val_loss: 6.1794e-04
# Epoch 11/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 4.5787e-04
# Epoch 12/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0233 - val_loss: 4.6417e-04
# Epoch 13/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0227 - val_loss: 4.3560e-04
# Epoch 14/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0220 - val_loss: 4.2510e-04
# Epoch 15/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0213 - val_loss: 4.2585e-04
# Epoch 16/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0207 - val_loss: 4.1802e-04
# Epoch 17/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0202 - val_loss: 3.9255e-04
# Epoch 18/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0196 - val_loss: 4.7530e-04
# Epoch 19/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0190 - val_loss: 4.2401e-04
# Epoch 20/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0187 - val_loss: 8.1320e-04
# 1/1 [==============================] - 0s 901us/step - loss: 0.0037
# Epoch 1/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.0686 - val_loss: 0.0033
# Epoch 2/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0216 - val_loss: 9.7709e-04
# Epoch 3/100
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0184 - val_loss: 0.0026
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0156 - val_loss: 0.0071
# Epoch 5/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 8.7598e-04
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0143 - val_loss: 0.0030
# Epoch 7/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0143 - val_loss: 2.9985e-04
# Epoch 8/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0129 - val_loss: 0.0017
# Epoch 9/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 2.6762e-04
# Epoch 10/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0032
# Epoch 11/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0020
# Epoch 12/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0050
# 1/1 [==============================] - 0s 868us/step - loss: 0.0027
# (0.002305431757122278, 0.0003, 'adamax', 10)

# %% [markdown]
# #### Deciding on best hyperparameter results

# %%
# We want the smallest loss
# 0 = least loss, 1 = learning rate, 2 = optimizer, 3 = neurons
if best_grid_search_model[0] > best_random_grid_model[0]:
  best_learning_rate = best_random_grid_model[1]
  best_optimizer = best_random_grid_model[2]
  best_neuron = best_random_grid_model[3]
else:
  best_learning_rate = best_grid_search_model[1]
  best_optimizer = best_grid_search_model[2]
  best_neuron = best_grid_search_model[3]
print(best_learning_rate)
print(best_optimizer)
print(best_neuron)
# Out:
# 0.003
# adam
# 15

# %% [markdown]
# # Best Model Prediction

# %%
best_param_model = lstm_model(best_learning_rate, best_neuron, best_optimizer)
best_param_model.fit(X_train, Y_train, epochs=150,batch_size=10,verbose=1)
loss = best_param_model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2347
# Epoch 2/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0451
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0302
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0260
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0214
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0200
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0177
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0159
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0160
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0152
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0150
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0142
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0138
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0134
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0150
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0131
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0126
# Epoch 19/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0132
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0141
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0116
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0114
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0111
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0108
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0101
# Epoch 26/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0118
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0103
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0089
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0085
# Epoch 30/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0069
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 34/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0052
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0060
# Epoch 38/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0093
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 47/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 48/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 49/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 50/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 51/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051
# Epoch 55/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 56/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 57/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 58/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 59/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 60/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 61/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 62/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 63/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 64/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 65/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 66/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 67/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 68/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 69/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 70/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 71/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 72/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 73/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 74/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 75/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 76/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 77/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 78/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 79/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0025
# Epoch 80/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 81/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 82/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0025
# Epoch 83/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 84/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 85/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 86/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 87/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 88/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 89/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 90/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 91/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 92/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 93/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 94/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 95/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 96/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 97/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 98/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 99/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 100/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 101/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 102/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 103/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 104/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 105/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 106/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 107/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 108/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 109/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 110/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 111/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 112/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 113/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 114/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 115/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 116/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 117/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 118/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 119/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 120/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 121/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 122/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 123/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 124/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 125/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 126/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 127/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 128/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0024
# Epoch 129/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 130/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 131/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 132/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 133/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 134/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 135/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 136/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 137/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 138/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 139/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0025
# Epoch 140/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 141/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 142/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 143/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 144/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 145/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 146/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 147/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 148/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 149/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 150/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0020
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020

# %% [markdown]
# # Using best model to predict on X_train & X_test

# %%
# Prediction and check performance metric
train_predict = best_param_model.predict(X_train)
test_predict = best_param_model.predict(X_test)
print(train_predict.shape)
print(test_predict.shape)
# Out:
# (128, 1)
# (9, 1)

# %% [markdown]
# # Performance Metric

# %%
def get_performance_train (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_train, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_train, model_pred).round(4))
  print('R2_Score:',r2_score(Y_train, model_pred).round(4))

# %%
def get_performance_test (model_pred):
  print('Mean Absolute Error:', mean_absolute_error(Y_test, model_pred).round(4))  
  print('Mean Squared Error:', mean_squared_error(Y_test, model_pred).round(4))  
  print('R2_Score:',r2_score(Y_test, model_pred).round(4))

# %%
print('Train:')
get_performance_train(train_predict)
print('\nTest:')
get_performance_test(test_predict)
# Out:
# Train:
# Mean Absolute Error: 0.0334
# Mean Squared Error: 0.0019
# R2_Score: 0.9625
#
# Test:
# Mean Absolute Error: 0.0415
# Mean Squared Error: 0.002
# R2_Score: -0.5357

# %% [markdown]
# # Plotting Train Prediction, Validation & Test Prediction Versus Actual Data

# %%
# Transform back to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict =scaler.inverse_transform(test_predict)

# %% [markdown]
# ### Train Predicted

# %%
look_back = 7

trainPredictPlot = np.empty_like(new_dataset) # shape
trainPredictPlot[:,:]= np.nan # values 0
trainPredictPlot[look_back:len(train_predict)+look_back] = train_predict # Populates: 7 -> 162 + 7 = 169

trainPredictPlot = [item[1] for item in trainPredictPlot]
plt.plot(trainPredictPlot, label="train_predict_price")

train_panda = pd.DataFrame(train_data)
plt.plot(scaler.inverse_transform(train_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()

# %% [markdown]
# ## Using last 7 days of training data to predict validation data.

# %%
temp_input = train_data[-7:]

# %%
# Demonstrate prediction for the next e.g.4 days:

# Step 1. 7 days of feature = temp_input taken from the last 7 days of the training set
# Step 2  i is the day you are on and we want to predict 4 days: 0,1,2,3 (4 days)
# Step 3. Predict the 8th day on each of the 7 days,
# Step 4. Add this new predicted day to the list
# Step 5. Because we are now taking in the last 7 days + the new predicted value, the list is now size 8  
# Step 6. In order to take in 7 days at a time, we shift 1 to the right.
# Step 7. We reassign the X_train to the new 7 days
# Step 8. We predict the 8th day of the 7 days and continue the process
# Step 9. We then add the 8th day to the output list
# Step 10. We keep track of the 4 days by incrementing by i at the end-> i = i+1
# Step 11. Once we have predicted the 4 days, we return the list of 4 day values.


custom_day = len(valset_data)
lst_output=[]
n_steps=7
i=0
X_input = temp_input
while(i<custom_day):
  if(len(temp_input)>7):
    X_input=array(temp_input[1:])
    X_input=X_input.reshape((1,n_steps,2))
    Y_hat = best_param_model.predict(X_input)
    temp_input = np.append(temp_input, Y_hat)
    temp_input=temp_input[1:]
    lst_output.append(Y_hat[0][0])
    i=i+1
  else:
    X_input=X_input.reshape((1,n_steps,2))
    Y_hat = best_param_model.predict(X_input, verbose=0)
    temp_input = np.append(temp_input, Y_hat)
    lst_output.append(Y_hat[0][0])
    i=i+1
print(lst_output)
# Out:
# [0.54792124, 0.55930257, 0.56404495, 0.65557504, 0.66189265, 0.7343037, 0.7615673, 0.81934696, 0.8545824, 0.8999212, 0.9228037, 0.9424761, 0.9398653, 0.9308903, 0.9103026, 0.89024395, 0.86698395]

# %% [markdown]
# ## Plotting evaluation: Training Prediction of Validation Dataset

# %%
day_new = custom_day-1

# Predicted days from training
# Transform back to original value before normalised
custom_day_prediction = np.array(lst_output)
# print("Predicted validation:")
# print(custom_day_prediction)
plt.plot(custom_day_prediction, label="Predicted Validation Data")

# Transform back to original value before normalised
val_data = [item[1] for item in valset_data] 
custom_day_validation = val_data[:custom_day]
# print("Actual validation:")
# print(custom_day_validation)
plt.plot(custom_day_validation, label="Actual Validation Data")

# Information
rcParams['figure.figsize'] = 15,6
plt.title('Training Prediction of Validation Data', size = 20)
plt.xlabel('Days predicted')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Plot

# %%
look_back = 7

testPredictPlot = np.empty_like(new_dataset)
testPredictPlot[:,:]= np.nan
testPredictPlot[look_back:len(test_predict)+look_back] = test_predict
testPredictPlot = [item[1] for item in testPredictPlot]
plt.plot(testPredictPlot, label="test_predict")

test_panda = pd.DataFrame(test_data)
plt.plot(scaler.inverse_transform(test_panda), label="actual_price")

rcParams['figure.figsize'] = 15,6
plt.title('Analysis of train, test and actual', size = 20)
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend()
plt.show()
